# %% [markdown]
# # Which COVID-19 Vaccine is Best for You?
# ## DS4A Team 55 Preliminary EDA

# %%
import pandas as pd
import numpy as np
import math
import base64
import matplotlib.pyplot as plt
import seaborn as sns
from sodapy import Socrata
import zipfile
import statsmodels.formula.api as sm

# %%
# increase the size and quality of any plots we produce
import matplotlib as mpl
mpl.rcParams["figure.dpi"] = 300

# %% [markdown]
# ## state_vax.csv
# Vaccine administration data for states within the U.S., including the District of Columbia from 12/13/2020 to the present, updated daily.

# %%
client = Socrata(
        domain = "data.cdc.gov",
        app_token = "bsYMLkKAQhIIVd7wzBzp5BiCR",
        timeout=10
        )
results = client.get_all("unsk-b7fc")

# convert to pandas DataFrame
df = pd.DataFrame.from_records(results)
df.sample(10)
# Out:
#                           date mmwr_week location distributed  \
# 17968  2021-06-11T00:00:00.000        23       PR     3905710
# 6956   2021-11-28T00:00:00.000        48       AZ    11718130
# 14948  2021-07-27T00:00:00.000        30       FL    25813915
# 20204  2021-05-07T00:00:00.000        18       CT     4034395
# 19437  2021-05-19T00:00:00.000        20       IA     3160085
# 6354   2021-12-07T00:00:00.000        49       OK     6083560
# 7402   2021-11-21T00:00:00.000        47       MT     1624975
# 24851  2021-02-25T00:00:00.000         8       IL     3499685
# 10111  2021-10-10T00:00:00.000        41       NM     3023035
# 28422  2021-01-01T00:00:00.000        53       AR      144225
#
#       distributed_janssen distributed_moderna distributed_pfizer  \
# 17968              190000             1741140            1974570
# 6956               547000             4632820            6538310
# 14948             1694500            10485300           13634115
# 20204              234700             1652940            2146755
# 19437              177500             1350240            1632345
# 6354               303800             2494840            3284920
# 7402                96900              677360             850715
# 24851                   0                   0                  0
# 10111              147400             1264200            1611435
# 28422                   0                   0                  0
#
#       distributed_unk_manuf dist_per_100k distributed_per_100k_12plus  ...  \
# 17968                     0        122294                      137125  ...
# 6956                      0        160992                      188818  ...
# 14948                     0        120189                      138072  ...
# 20204                     0        113158                           0  ...
# 19437                     0        100159                      118077  ...
# 6354                      0        153743                      182952  ...
# 7402                      0        152040                      177090  ...
# 24851                     0         27618                           0  ...
# 10111                     0        144172                      169127  ...
# 28422                     0          4779                           0  ...
#
#       administered_dose1_recip_5pluspop_pct series_complete_5plus  \
# 17968                                     0                     0
# 6956                                   67.8               3961602
# 14948                                     0                     0
# 20204                                     0                     0
# 19437                                     0                     0
# 6354                                   68.1               2062824
# 7402                                   62.7                551366
# 24851                                     0                     0
# 10111                                     0                     0
# 28422                                     0                     0
#
#       series_complete_5pluspop_pct administered_5plus admin_per_100k_5plus  \
# 17968                            0                  0                    0
# 6956                          57.8            9457517               138088
# 14948                            0                  0                    0
# 20204                            0                  0                    0
# 19437                            0                  0                    0
# 6354                          55.7            4998142               135032
# 7402                          54.7            1296204               128640
# 24851                            0                  0                    0
# 10111                            0                  0                    0
# 28422                            0                  0                    0
#
#       distributed_per_100k_5plus series_complete_moderna_5plus  \
# 17968                          0                           NaN
# 6956                      171094                       1525154
# 14948                          0                           NaN
# 20204                          0                           NaN
# 19437                          0                           NaN
# 6354                      164357                        804469
# 7402                      161268                        224316
# 24851                          0                           NaN
# 10111                          0                           NaN
# 28422                          0                           NaN
#
#       series_complete_pfizer_5plus series_complete_janssen_5plus  \
# 17968                          NaN                           NaN
# 6956                       2128578                        302627
# 14948                          NaN                           NaN
# 20204                          NaN                           NaN
# 19437                          NaN                           NaN
# 6354                       1126540                        131660
# 7402                        276725                         49969
# 24851                          NaN                           NaN
# 10111                          NaN                           NaN
# 28422                          NaN                           NaN
#
#       series_complete_unk_manuf_5plus
# 17968                             NaN
# 6956                             5243
# 14948                             NaN
# 20204                             NaN
# 19437                             NaN
# 6354                              155
# 7402                              356
# 24851                             NaN
# 10111                             NaN
# 28422                             NaN
#
# [10 rows x 82 columns]

# %%
df.columns
# Out:
# Index(['date', 'mmwr_week', 'location', 'distributed', 'distributed_janssen',
#        'distributed_moderna', 'distributed_pfizer', 'distributed_unk_manuf',
#        'dist_per_100k', 'distributed_per_100k_12plus',
#        'distributed_per_100k_18plus', 'distributed_per_100k_65plus',
#        'administered', 'administered_12plus', 'administered_18plus',
#        'administered_65plus', 'administered_janssen', 'administered_moderna',
#        'administered_pfizer', 'administered_unk_manuf', 'admin_per_100k',
#        'admin_per_100k_12plus', 'admin_per_100k_18plus',
#        'admin_per_100k_65plus', 'recip_administered',
#        'administered_dose1_recip', 'administered_dose1_pop_pct',
#        'administered_dose1_recip_1', 'administered_dose1_recip_2',
#        'administered_dose1_recip_3', 'administered_dose1_recip_4',
#        'administered_dose1_recip_5', 'administered_dose1_recip_6',
#        'series_complete_yes', 'series_complete_pop_pct',
#        'series_complete_12plus', 'series_complete_12pluspop',
#        'series_complete_18plus', 'series_complete_18pluspop',
#        'series_complete_65plus', 'series_complete_65pluspop',
#        'series_complete_janssen', 'series_complete_moderna',
#        'series_complete_pfizer', 'series_complete_unk_manuf',
#        'series_complete_janssen_12plus', 'series_complete_moderna_12plus',
#        'series_complete_pfizer_12plus', 'series_complete_unk_manuf_1',
#        'series_complete_janssen_18plus', 'series_complete_moderna_18plus',
#        'series_complete_pfizer_18plus', 'series_complete_unk_manuf_2',
#        'series_complete_janssen_65plus', 'series_complete_moderna_65plus',
#        'series_complete_pfizer_65plus', 'series_complete_unk_manuf_3',
#        'additional_doses', 'additional_doses_vax_pct',
#        'additional_doses_12plus', 'additional_doses_12plus_vax_pct',
#        'additional_doses_18plus', 'additional_doses_18plus_vax_pct',
#        'additional_doses_50plus', 'additional_doses_50plus_vax_pct',
#        'additional_doses_65plus', 'additional_doses_65plus_vax_pct',
#        'additional_doses_moderna', 'additional_doses_pfizer',
#        'additional_doses_janssen', 'additional_doses_unk_manuf',
#        'administered_dose1_recip_5plus',
#        'administered_dose1_recip_5pluspop_pct', 'series_complete_5plus',
#        'series_complete_5pluspop_pct', 'administered_5plus',
#        'admin_per_100k_5plus', 'distributed_per_100k_5plus',
#        'series_complete_moderna_5plus', 'series_complete_pfizer_5plus',
#        'series_complete_janssen_5plus', 'series_complete_unk_manuf_5plus'],
#       dtype='object')

# %%
df.sort_values(by="date", ascending=True)
# Out:
#                           date mmwr_week location distributed  \
# 29591  2020-12-13T00:00:00.000        51       AS        3900
# 29586  2020-12-13T00:00:00.000        51       US       13650
# 29587  2020-12-13T00:00:00.000        51       GU        3900
# 29590  2020-12-13T00:00:00.000        51      LTC           0
# 29589  2020-12-13T00:00:00.000        51       MP        4875
# ...                        ...       ...      ...         ...
# 36     2022-03-16T00:00:00.000        11       NC    21096800
# 35     2022-03-16T00:00:00.000        11       NE     3800810
# 34     2022-03-16T00:00:00.000        11       PA    29098425
# 32     2022-03-16T00:00:00.000        11       GA    20870895
# 0      2022-03-16T00:00:00.000        11       PW       43990
#
#       distributed_janssen distributed_moderna distributed_pfizer  \
# 29591                   0                   0                  0
# 29586                   0                   0                  0
# 29587                   0                   0                  0
# 29590                   0                   0                  0
# 29589                   0                   0                  0
# ...                   ...                 ...                ...
# 36                 920500             7946860           12229440
# 35                 149700             1337780            2313330
# 34                1509600            11057160           16531665
# 32                 821500             8131140           11918255
# 0                    3800               28500              11690
#
#       distributed_unk_manuf dist_per_100k distributed_per_100k_12plus  ...  \
# 29591                     0          7003                           0  ...
# 29586                     0             4                           0  ...
# 29587                     0          2353                           0  ...
# 29590                     0             0                           0  ...
# 29589                     0          8570                           0  ...
# ...                     ...           ...                         ...  ...
# 36                        0        201150                      234787  ...
# 35                        0        196484                      234994  ...
# 34                        0        227296                      262585  ...
# 32                        0        196572                      232206  ...
# 0                         0        204301                      235935  ...
#
#       administered_dose1_recip_5pluspop_pct series_complete_5plus  \
# 29591                                     0                     0
# 29586                                     0                     0
# 29587                                     0                     0
# 29590                                     0                     0
# 29589                                     0                     0
# ...                                     ...                   ...
# 36                                     87.9               6257837
# 35                                     74.6               1214568
# 34                                     88.5               8620888
# 32                                     68.9               5732834
# 0                                        95                 17998
#
#       series_complete_5pluspop_pct administered_5plus admin_per_100k_5plus  \
# 29591                            0                  0                    0
# 29586                            0                  0                    0
# 29587                            0                  0                    0
# 29590                            0                  0                    0
# 29589                            0                  0                    0
# ...                            ...                ...                  ...
# 36                            63.3           16242181               164423
# 35                            67.3            3100711               171925
# 34                            71.2           22240115               183741
# 32                            57.6           14483375               145403
# 0                             88.3              46855               229986
#
#       distributed_per_100k_5plus series_complete_moderna_5plus  \
# 29591                          0                           NaN
# 29586                          0                           NaN
# 29587                          0                           NaN
# 29590                          0                           NaN
# 29589                          0                           NaN
# ...                          ...                           ...
# 36                        213567                       2165500
# 35                        210743                        412936
# 34                        240402                       3085568
# 32                        209529                       2123315
# 0                         215923                         12615
#
#       series_complete_pfizer_5plus series_complete_janssen_5plus  \
# 29591                          NaN                           NaN
# 29586                          NaN                           NaN
# 29587                          NaN                           NaN
# 29590                          NaN                           NaN
# 29589                          NaN                           NaN
# ...                            ...                           ...
# 36                         3611259                        480931
# 35                          712410                         87625
# 34                         4816533                        718129
# 32                         3281450                        316476
# 0                             2992                          2352
#
#       series_complete_unk_manuf_5plus
# 29591                             NaN
# 29586                             NaN
# 29587                             NaN
# 29590                             NaN
# 29589                             NaN
# ...                               ...
# 36                                147
# 35                               1597
# 34                                658
# 32                              11593
# 0                                  39
#
# [29592 rows x 82 columns]

# %%
# df.shape

# %%
# remove all distribution cols
# remove "Administered", this is the total for 1st dose and complete series
# remove all 5plus cols, very recently approved and sporadic across states
# remove additional doses for 50plus, age group doesn't show up elsewhere in dataset


df = df.drop(columns= ["mmwr_week","distributed", "distributed_janssen", "distributed_moderna", 
                       "distributed_pfizer", "distributed_unk_manuf", "dist_per_100k","distributed_per_100k_12plus",
                       "distributed_per_100k_18plus", "distributed_per_100k_65plus", "distributed_per_100k_5plus",
                       "administered","administered_dose1_recip_5plus", "recip_administered",
                       "administered_dose1_recip_5pluspop_pct", "series_complete_5plus", "series_complete_5pluspop_pct", 
                       "administered_5plus", "admin_per_100k_5plus", "series_complete_moderna_5plus",
                       "series_complete_pfizer_5plus", "series_complete_janssen_5plus", "series_complete_unk_manuf_5plus",
                       "additional_doses_50plus", "additional_doses_50plus_vax_pct"], axis=1)

# %%
# abbreviating column names for readability
# cols in api data are labelled differently than csv directly from data.cdc.gov, values match up so renaming those cols

rename_cols = {"administered_12plus":"admin_12plus",
               "location":"state",
               "administered_18plus":"admin_18plus",
               "administered_65plus":"admin_65plus",
               "administered_janssen":"admin_janssen",
               "administered_moderna":"admin_moderna",
               "administered_pfizer":"admin_pfizer",
               "administered_unk_manuf":"admin_unk",
               "administered_dose1_recip":"admin_dose1",
               "administered_dose1_pop_pct":"admin_dose1_pop_pct",
               "administered_dose1_recip_1":"admin_dose1_12plus",
               "administered_dose1_recip_2":"admin_dose1_12plus_pop_pct",
               "administered_dose1_recip_3":"admin_dose1_18plus",
               "administered_dose1_recip_4":"admin_dose1_18plus_pop_pct",
               "administered_dose1_recip_5":"admin_dose1_65plus",
               "administered_dose1_recip_6":"admin_dose1_65plus_pop_pct",
               "series_complete_yes":"series_complete",
               "series_complete_12pluspop":"series_complete_12plus_pop_pct",
               "series_complete_18pluspop":"series_complete_18plus_pop_pct",
               "series_complete_65pluspop":"series_complete_65plus_pop_pct",
               "series_complete_unk_manuf":"series_complete_unk",
               "series_complete_unk_manuf_1":"series_complete_unk_12plus",
               "series_complete_unk_manuf_2":"series_complete_unk_18plus",
               "series_complete_unk_manuf_3":"series_complete_unk_65plus",
               "series_complete_12pluspop_pct":"series_complete_12plus_pop_pct",
               "series_complete_18pluspop_pct":"series_complete_18plus_pop_pct",
               "series_complete_65pluspop_pct":"series_complete_65plus_pop_pct"
               }
df = df.rename(columns=rename_cols)

# %%
# df.columns

# %%
# see data types of df
# all types = object, need to change to ints and floats
# df.dtypes

# %%
# show cols with NaNs
# cols with NaNs are additional dose cols, after investigating this happens when other additional dose cols are 0
df.columns[df.isnull().any()]
# Out:
# Index(['additional_doses', 'additional_doses_vax_pct',
#        'additional_doses_12plus', 'additional_doses_12plus_vax_pct',
#        'additional_doses_18plus', 'additional_doses_18plus_vax_pct',
#        'additional_doses_65plus', 'additional_doses_65plus_vax_pct',
#        'additional_doses_moderna', 'additional_doses_pfizer',
#        'additional_doses_janssen', 'additional_doses_unk_manuf'],
#       dtype='object')

# %%
# replace NaNs with 0 to fill in values
nan_col = ['additional_doses', 'additional_doses_vax_pct', 'additional_doses_12plus',
           'additional_doses_18plus', 'additional_doses_12plus_vax_pct', 'additional_doses_18plus_vax_pct',
           'additional_doses_65plus', 'additional_doses_65plus_vax_pct',
           'additional_doses_moderna', 'additional_doses_pfizer',
           'additional_doses_janssen', 'additional_doses_unk_manuf']
df[nan_col] = df[nan_col].fillna(0)

# %%
to_int = ['admin_12plus', 'admin_18plus', 'admin_65plus','admin_janssen',
          'admin_moderna', 'admin_pfizer', 'admin_unk','admin_per_100k',
          'admin_per_100k_12plus', 'admin_per_100k_18plus','admin_per_100k_65plus',
          'admin_dose1', 'admin_dose1_12plus', 'admin_dose1_18plus',
          'admin_dose1_65plus', 'series_complete_12plus', 'series_complete_18plus',
          'series_complete','series_complete_65plus', 'series_complete_janssen', 'series_complete_moderna',
          'series_complete_pfizer','series_complete_unk', 'series_complete_janssen_12plus',
          'series_complete_moderna_12plus', 'series_complete_pfizer_12plus', 'series_complete_unk_12plus',
          'series_complete_janssen_18plus', 'series_complete_moderna_18plus', 'series_complete_pfizer_18plus',
          'series_complete_unk_18plus', 'series_complete_janssen_65plus', 'series_complete_moderna_65plus',
          'series_complete_pfizer_65plus', 'series_complete_unk_65plus', 'additional_doses', 'additional_doses_12plus',
          'additional_doses_18plus', 'additional_doses_65plus', 'additional_doses_moderna',
          'additional_doses_pfizer', 'additional_doses_janssen', 'additional_doses_unk_manuf'
         ]

to_float = ['admin_dose1_pop_pct', 'admin_dose1_12plus_pop_pct', 'admin_dose1_18plus_pop_pct',
            'admin_dose1_65plus_pop_pct', 'series_complete_pop_pct', 'series_complete_12plus_pop_pct',
            'series_complete_12plus_pop_pct', 'series_complete_18plus_pop_pct', 'series_complete_65plus_pop_pct',
            'additional_doses_vax_pct', 'additional_doses_12plus_vax_pct', 'additional_doses_18plus_vax_pct', 'additional_doses_65plus_vax_pct'
           ]

df[to_int] = df[to_int].astype("int")
df[to_float] = df[to_float].astype("float")

# %%
# checking that data types hace been converted correctly
# df.dtypes

# %%
# removing locations outside of the contential united states as well as united states total

drop_location = ["AS", "BP2", "DD2", "FM", "GU",
                 "IH2", "MH", "MP", "PR", "RP",
                 "US", "VA2", "VI", "LTC"]
df = df[~df["state"].isin(drop_location)]

# checking that location vals = 51, including DC

df.state.nunique()
# Out:
# 52

# %%
# converting "date" col to datetime
df["date"] = pd.to_datetime(df["date"])

# %%
# filter location to New York
df_ny = df.loc[df["state"] == "NY"]

# %%
# creating a new df with all values on a daily basis instead of a running total
ny_daily = df_ny.drop(columns="state").set_index("date")
df_ny_daily = ny_daily.diff(periods=-1)
# df_ny_daily.head(50)

# %%
# this value appears as an outlier but was manually calculated from raw dataset and is correct
print(df_ny_daily["admin_pfizer"].max())
# Out:
# 581745.0

# %%
# set index to date to extract rows for the first of each month, aligns with how other datasets are reported
df_ny_m = df_ny.set_index("date")
df_ny_m = df_ny_m.groupby(df_ny_m.index.strftime("%Y-%m")).tail(1)
df_ny_m = df_ny_m.reset_index().sort_values(by="date", ascending=True)
# df_ny_m.head(10)

# %%
# first reported date and most recent date for vax data, updated daily
print(df_ny["date"].min())
print(df_ny["date"].max())
# Out:
# 2020-12-14 00:00:00
# 2022-03-16 00:00:00

# %% [markdown]
# # covid_cases
# Covid cases in NY

# %%
# #read data
# covid_df = pd.read_csv("data/covid_cases_4states.csv.zip", compression="zip")
# covid_df.head()

with zipfile.ZipFile("data/covid_cases_4states.csv.zip") as z:
    with z.open("covid_cases_4states.csv") as f:
        covid_df = pd.read_csv(f, low_memory=False)

covid_df.head()
# # open zipped dataset
# with zipfile.ZipFile("test.zip") as z:
#    # open the csv file in the dataset
#    with z.open("test.csv") as f:
       
#       # read the dataset
#       train = pd.read_csv(f)
# Out:
#   case_month res_state  state_fips_code res_county  county_fips_code  \
# 0    2021-10        IL               17  VERMILION           17183.0
# 1    2021-10        NY               36    CLINTON           36019.0
# 2    2021-10        IL               17  EFFINGHAM           17049.0
# 3    2021-09        IL               17        LEE           17103.0
# 4    2020-04        IL               17     DUPAGE           17043.0
#
#         age_group     sex     race        ethnicity  \
# 0  18 to 49 years  Female  Missing          Missing
# 1       65+ years  Female  Missing              NaN
# 2  18 to 49 years  Female    White          Missing
# 3  18 to 49 years    Male    White          Missing
# 4  18 to 49 years    Male  Missing  Hispanic/Latino
#
#    case_positive_specimen_interval  case_onset_interval  process exposure_yn  \
# 0                              NaN                  0.0  Missing     Missing
# 1                              NaN                  NaN  Missing     Missing
# 2                              NaN                  0.0  Missing     Missing
# 3                              NaN                  0.0  Missing     Missing
# 4                              NaN                  0.0  Missing     Missing
#
#               current_status symptom_status  hosp_yn   icu_yn death_yn  \
# 0  Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 1  Laboratory-confirmed case        Missing  Missing  Missing       No
# 2              Probable Case        Missing  Missing  Missing  Missing
# 3  Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 4  Laboratory-confirmed case        Missing       No  Unknown  Unknown
#
#   underlying_conditions_yn
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
covid_df.columns #column names
# Out:
# Index(['case_month', 'res_state', 'state_fips_code', 'res_county',
#        'county_fips_code', 'age_group', 'sex', 'race', 'ethnicity',
#        'case_positive_specimen_interval', 'case_onset_interval', 'process',
#        'exposure_yn', 'current_status', 'symptom_status', 'hosp_yn', 'icu_yn',
#        'death_yn', 'underlying_conditions_yn'],
#       dtype='object')

# %%
# covid_df.dtypes

# %%
covid_df.shape
# Out:
# (13785863, 19)

# %%
#data cleaning
covid_df['case_month'] = pd.to_datetime(covid_df['case_month']) #convert to date

# %%
# dropping irrelevant columns
covid_df = covid_df.drop(columns=["case_positive_specimen_interval", "case_onset_interval", "process", "exposure_yn", "current_status"])

# %%
# rename cols for readability and uniformify across datasets
covid_rename = {"case_month":"date", "res_state":"state",
               "res_county":"county"}

covid_df = covid_df.rename(columns=covid_rename)

# %%
# converting data types 
to_str = ["state", "county", "age_group", "sex", "race", "ethnicity",
          "symptom_status", "hosp_yn", "icu_yn", "death_yn", "underlying_conditions_yn"]
covid_df[to_str] = covid_df[to_str].astype(str)

# %%
# show cols with NaNs
covid_df.columns[covid_df.isnull().any()]
# Out:
# Index(['county_fips_code'], dtype='object')

# %%
# fill NaNs in county_fips_code with "Not Available"
covid_df["county_fips_code"] = covid_df["county_fips_code"].fillna("Not Available")

# shows all values within the race col
covid_df.race.unique()

# rename nan, Missing, and Unknown to Not Available
rename_covid_nan = {"nan":"Not Available",
                     "Missing":"Not Available",
                     "Unknown":"Not Available"}
covid_df["race"] = covid_df["race"].replace(rename_covid_nan).astype(str)

# same treatment for ethnicity as the race col
covid_df.ethnicity.unique()

covid_df["ethnicity"] = covid_df["ethnicity"].replace(rename_covid_nan).astype(str)

covid_df["county"] = covid_df["county"].replace({"nan":"Not Available"})

# checking for NaN string values and replace with "Not Available" in remaining cols
covid_df.age_group.unique()
covid_df["age_group"] = covid_df["age_group"].replace({"nan":"Not Available", "Missing":"Not Available"}).astype(str)

covid_df["sex"] = covid_df["sex"].replace(rename_covid_nan).astype(str)

covid_df["death_yn"] = covid_df["death_yn"].replace(rename_covid_nan).astype(str)

covid_df["underlying_conditions_yn"] = covid_df["underlying_conditions_yn"].replace(rename_covid_nan).astype(str)

rename_missing_unk = {"Missing":"Not Available",
                      "Unknown":"Not Available"}
rename_col = ["symptom_status", "hosp_yn", "icu_yn"]
covid_df[rename_col] = covid_df[rename_col].replace(rename_missing_unk).astype(str)

# %%
covid_df.sample(10, random_state = 42)
# Out:
#                date state  state_fips_code       county county_fips_code  \
# 7927990  2021-03-01    NY               36     NEW YORK          36061.0
# 4042929  2021-08-01    FL               12      BROWARD          12011.0
# 9625198  2021-08-01    CA                6       ORANGE           6059.0
# 4193583  2021-10-01    FL               12    ST. LUCIE          12111.0
# 5676551  2021-05-01    CA                6  LOS ANGELES           6037.0
# 1311784  2020-07-01    FL               12         POLK          12105.0
# 339610   2021-12-01    NY               36     TOMPKINS          36109.0
# 2067531  2020-12-01    NY               36      STEUBEN          36101.0
# 10372618 2020-09-01    FL               12      BROWARD          12011.0
# 10162945 2021-11-01    CA                6    RIVERSIDE           6065.0
#
#                age_group            sex           race            ethnicity  \
# 7927990     0 - 17 years         Female  Not Available        Not Available
# 4042929        65+ years           Male  Not Available        Not Available
# 9625198   18 to 49 years         Female          White  Non-Hispanic/Latino
# 4193583   18 to 49 years         Female  Not Available        Not Available
# 5676551     0 - 17 years  Not Available          White      Hispanic/Latino
# 1311784     0 - 17 years           Male          White      Hispanic/Latino
# 339610    18 to 49 years         Female          White        Not Available
# 2067531   50 to 64 years  Not Available  Not Available        Not Available
# 10372618    0 - 17 years           Male          White      Hispanic/Latino
# 10162945       65+ years           Male          White        Not Available
#
#          symptom_status        hosp_yn         icu_yn       death_yn  \
# 7927990     Symptomatic  Not Available  Not Available  Not Available
# 4042929   Not Available  Not Available  Not Available             No
# 9625198   Not Available  Not Available  Not Available  Not Available
# 4193583   Not Available  Not Available  Not Available  Not Available
# 5676551   Not Available             No  Not Available  Not Available
# 1311784   Not Available            Yes  Not Available             No
# 339610    Not Available  Not Available  Not Available             No
# 2067531   Not Available  Not Available  Not Available  Not Available
# 10372618  Not Available             No  Not Available             No
# 10162945  Not Available  Not Available  Not Available  Not Available
#
#          underlying_conditions_yn
# 7927990             Not Available
# 4042929             Not Available
# 9625198             Not Available
# 4193583             Not Available
# 5676551             Not Available
# 1311784             Not Available
# 339610              Not Available
# 2067531             Not Available
# 10372618            Not Available
# 10162945            Not Available

# %%
covid_df.groupby(['sex']).size().plot.bar()
plt.title("COVID-19 Cases by sex")
plt.show()

# %%
# covid_df.describe(include = 'all',datetime_is_numeric=True) #describe and include string columns

# %%
#covid cases trend
# trend_df = covid_df.groupby(['date']).size().reset_index(name = 'case_count').set_index('date')
# trend_df['case_count_per_100k'] = trend_df['case_count']/100000
# plt.plot(trend_df.index,trend_df['case_count_per_100k'])
# plt.title('COVID-19 Cases Have Spiked Twice And Is Trending Upwards')
# plt.xlabel('Date')
# plt.ylabel('Case Count (Hundred Thousand)')
# plt.xticks(rotation=90)
# plt.show()

# %%
# trend_df.head()

# %%
# comparing cases with vaccine administration rates
# case_vax_ax = ny_m_plt.plot(x="date", y=["admin_per_100k_12plus", "admin_per_100k_18plus", "admin_per_100k_65plus"], kind="line")
# trend_df.plot(y="case_count", kind="line", ax=case_vax_ax, title="COVID-19 Cases and Vaccinations per Age Group");

# %% [markdown]
# When comparing the COVID case trends with the trends in vaccine administration across each age group, it can be seen that the number of cases starts to sharply decline as the population recieves the vaccine. The case_count trend line was already falling when the vaccines were made available. However, once more of the population started to get vaccinated the case numbers stayed low up until the omicron variant began spreading around November of 2021 up until now (mid-January 2022).

# %%
# case_comp_ax = daily_plt.plot(x="date", y='series_complete', kind="line")
# trend_df.plot(y="case_count", kind="line", ax=case_comp_ax, title="COVID-19 Cases and Complete Vaccine Series");

# %%
# covid_65plus = covid_df.loc[covid_df["age_group"] == "65+ years"]

# %%
# df_covid65 = covid_65plus.groupby(['date']).size().reset_index(name = 'case_count').set_index('date')

# df_covid65.plot(title="Trend in COVID-19 Cases for Age 65+");

# %%
# covid65_ax = ny_m_plt.plot(x="date", y="admin_per_100k_65plus", kind="line")
# df_covid65.plot(y="case_count", kind="line", ax=covid65_ax, title="COVID-19 Cases and Vaccinations for Age 65+");

# %% [markdown]
# # Average Number of Cases Before and After the Release of COVID-19 Vaccines
# #### Is the number of cases before and after the deployment of COVID-19 vaccines statiscally significant?

# %%
# firstly, according to the CDC's vaccination dataset, when is the first recorded vaccination date?
df2 = df
df2 = df2.set_index("date")
df2 = df2.loc[(df2 !=0).any(axis=1), :]
df2 = df2.sort_values(by="date",ascending=True)
df2

# the earliest date of vaccine administration from any manufacturer is Dec 14, 2020 
# this was verified by visual inspection of the dataset
# Out:
#            state  admin_12plus  admin_18plus  admin_65plus  admin_janssen  \
# date
# 2020-12-14    TN             0             0             0              0
# 2020-12-14    LA             0             0             0              0
# 2020-12-14    WI             0             0             0              0
# 2020-12-14    MI             0             0             0              0
# 2020-12-14    VA             0             0             0              0
# ...          ...           ...           ...           ...            ...
# 2022-03-16    NE       2997230       2795044        820777          93646
# 2022-03-16    PA      21558528      20295827       6218082         771145
# 2022-03-16    GA      14127104      13247503       3439592         336917
# 2022-03-16    CA      69579019      64384808      14743728        2289012
# 2022-03-16    PW         44502         40954          4896           2347
#
#             admin_moderna  admin_pfizer  admin_unk  admin_per_100k  \
# date
# 2020-12-14              0             0          0               0
# 2020-12-14              0             0          0               0
# 2020-12-14              0             0          0               0
# 2020-12-14              0             0          0               0
# 2020-12-14              0             0          0               0
# ...                   ...           ...        ...             ...
# 2022-03-16        1114319       1886932       6181          160311
# 2022-03-16        8559062      12911783       1446          173750
# 2022-03-16        5624904       8484610      39018          136431
# 2022-03-16       26919783      42979740      15399          182738
# 2022-03-16          35993          8438         80          217620
#
#             admin_per_100k_12plus  ...  additional_doses_12plus  \
# date                               ...
# 2020-12-14                      0  ...                        0
# 2020-12-14                      0  ...                        0
# 2020-12-14                      0  ...                        0
# 2020-12-14                      0  ...                        0
# 2020-12-14                      0  ...                        0
# ...                           ...  ...                      ...
# 2022-03-16                 185311  ...                   591001
# 2022-03-16                 194545  ...                  3578914
# 2022-03-16                 157176  ...                  2042448
# 2022-03-16                 206796  ...                 13726617
# 2022-03-16                 238681  ...                    11175
#
#             additional_doses_12plus_vax_pct  additional_doses_18plus  \
# date
# 2020-12-14                              0.0                        0
# 2020-12-14                              0.0                        0
# 2020-12-14                              0.0                        0
# 2020-12-14                              0.0                        0
# 2020-12-14                              0.0                        0
# ...                                     ...                      ...
# 2022-03-16                             50.6                   570582
# 2022-03-16                             43.0                  3465404
# 2022-03-16                             36.5                  1990336
# 2022-03-16                             51.2                 13160958
# 2022-03-16                             65.7                    10569
#
#             additional_doses_18plus_vax_pct  additional_doses_65plus  \
# date
# 2020-12-14                              0.0                        0
# 2020-12-14                              0.0                        0
# 2020-12-14                              0.0                        0
# 2020-12-14                              0.0                        0
# 2020-12-14                              0.0                        0
# ...                                     ...                      ...
# 2022-03-16                             52.8                   212568
# 2022-03-16                             44.4                  1390194
# 2022-03-16                             38.1                   689470
# 2022-03-16                             53.4                  3705676
# 2022-03-16                             67.8                     1500
#
#             additional_doses_65plus_vax_pct  additional_doses_moderna  \
# date
# 2020-12-14                              0.0                         0
# 2020-12-14                              0.0                         0
# 2020-12-14                              0.0                         0
# 2020-12-14                              0.0                         0
# 2020-12-14                              0.0                         0
# ...                                     ...                       ...
# 2022-03-16                             74.6                    231087
# 2022-03-16                             62.8                   1569840
# 2022-03-16                             55.1                    909118
# 2022-03-16                             71.3                   5938030
# 2022-03-16                             83.8                     10337
#
#             additional_doses_pfizer  additional_doses_janssen  \
# date
# 2020-12-14                        0                         0
# 2020-12-14                        0                         0
# 2020-12-14                        0                         0
# 2020-12-14                        0                         0
# 2020-12-14                        0                         0
# ...                             ...                       ...
# 2022-03-16                   353198                      6489
# 2022-03-16                  1950377                     59273
# 2022-03-16                  1108268                     24129
# 2022-03-16                  7573076                    216853
# 2022-03-16                      839                         0
#
#             additional_doses_unk_manuf
# date
# 2020-12-14                           0
# 2020-12-14                           0
# 2020-12-14                           0
# 2020-12-14                           0
# 2020-12-14                           0
# ...                                ...
# 2022-03-16                         342
# 2022-03-16                          62
# 2022-03-16                        1515
# 2022-03-16                         540
# 2022-03-16                           0
#
# [23400 rows x 56 columns]

# %%
case_prevax1 = covid_df[~covid_df["state"].isin(["TX"])]
case_prevax1 = case_prevax1.groupby("date", as_index=False).size()
case_prevax1 = case_prevax1.rename(columns={"size":"cases"})
case_prevax1 = case_prevax1[(case_prevax1["date"] <= "2020-12-01")]
case_prevax1 
print("The average number of cases BEFORE vaccine release is:")
print(case_prevax1["cases"].mean())
# Out:
# The average number of cases BEFORE vaccine release is:
# 480397.5833333333

# %%
# assuming that the vaccines take ~ 1 month to become effective
case_prevax1 = covid_df[~covid_df["state"].isin(["TX"])]
case_prevax1 = case_prevax1.groupby("date", as_index=False).size()
case_prevax1 = case_prevax1.rename(columns={"size":"cases"})
case_prevax1 = case_prevax1[(case_prevax1["date"] <= "2021-02-01")]
case_prevax1 
print("The average number of cases BEFORE vaccine release is:")
print(case_prevax1["cases"].mean())
# Out:
# The average number of cases BEFORE vaccine release is:
# 564783.5714285715

# %%
case_prevax1
# Out:
#          date    cases
# 0  2020-01-01      971
# 1  2020-02-01     1868
# 2  2020-03-01   182583
# 3  2020-04-01   352624
# 4  2020-05-01   278068
# 5  2020-06-01   346750
# 6  2020-07-01   519825
# 7  2020-08-01   406416
# 8  2020-09-01   323389
# 9  2020-10-01   529376
# 10 2020-11-01   981166
# 11 2020-12-01  1841735
# 12 2021-01-01  1545295
# 13 2021-02-01   596904

# %%
case_prevax1.plot(x = "date", y = "cases")
# Out:
# <AxesSubplot:xlabel='date'>

# %%
case_postvax1 = covid_df[~covid_df["state"].isin(["TX"])]
case_postvax1 = case_postvax1.groupby("date", as_index=False).size()
case_postvax1 = case_postvax1.rename(columns={"size":"cases"})
case_postvax1 = case_postvax1[(case_postvax1["date"] > "2020-12-01")]

print("The average number of cases AFTER vaccine release is:")
print(case_postvax1["cases"].mean())
# Out:
# The average number of cases AFTER vaccine release is:
# 668424.3333333334

# %%
# assuming that the vaccines take ~ 1 month to become effective
case_postvax1 = covid_df[~covid_df["state"].isin(["TX"])]
case_postvax1 = case_postvax1.groupby("date", as_index=False).size()
case_postvax1 = case_postvax1.rename(columns={"size":"cases"})
case_postvax1 = case_postvax1[(case_postvax1["date"] > "2021-02-01")]

print("The average number of cases AFTER vaccine release is:")
print(case_postvax1["cases"].mean())
# Out:
# The average number of cases AFTER vaccine release is:
# 587889.3

# %%
case_postvax1.plot(x="date", y="cases")
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# # Analyzing the Impact of Different Factors on Case Trends
# ### Applying multiple regression to a new data frame containing case counts for each state by month, vaccine administration per month for each manufacturer, and analyzing demographic factors

# %%
# working with covid_cases_4state.csv dataframe, i.e. covid_df
# cases per state

cases_df = covid_df.groupby(["date", "state"], as_index=False).size()
cases_df = cases_df.rename(columns={"size":"cases"})
cases_df = cases_df[~(cases_df["date"] <= "2020-12-01")]

# %%
# exporting covid cases per month to csv

# cases_df.to_csv("covid_cases.csv", index=False)

# %%
# converting state names to numerics to fit regression line
# CA:1, FL:2, NY:3, IL:4
numstate = {"CA":1, "FL":2, "NY":3, "IL":4}
cases_df["state"] = cases_df["state"].replace(numstate)

# %%
cases_df
# Out:
#          date  state   cases
# 47 2021-01-01      1  877185
# 48 2021-01-01      2  207612
# 49 2021-01-01      4  127099
# 50 2021-01-01      3  333399
# 51 2021-02-01      1  182380
# 52 2021-02-01      2  165000
# 53 2021-02-01      4   50197
# 54 2021-02-01      3  199327
# 55 2021-03-01      1   83365
# 56 2021-03-01      2  330204
# 57 2021-03-01      4   70218
# 58 2021-03-01      3  222687
# 59 2021-04-01      1   65972
# 60 2021-04-01      2  111786
# 61 2021-04-01      4   81205
# 62 2021-04-01      3  144255
# 63 2021-05-01      1   38232
# 64 2021-05-01      2   54597
# 65 2021-05-01      4   31940
# 66 2021-05-01      3   42055
# 67 2021-06-01      1   35709
# 68 2021-06-01      2   49974
# 69 2021-06-01      4    9547
# 70 2021-06-01      3   12562
# 71 2021-07-01      1  203143
# 72 2021-07-01      2  115593
# 73 2021-07-01      4   49716
# 74 2021-07-01      3   47079
# 75 2021-08-01      1  414353
# 76 2021-08-01      2  268491
# 77 2021-08-01      4  115425
# 78 2021-08-01      3  125079
# 79 2021-09-01      1  251191
# 80 2021-09-01      2  287957
# 81 2021-09-01      4   90863
# 82 2021-09-01      3  138688
# 83 2021-10-01      1  178486
# 84 2021-10-01      2  183619
# 85 2021-10-01      4   74841
# 86 2021-10-01      3  117439
# 87 2021-11-01      1  163753
# 88 2021-11-01      2   46151
# 89 2021-11-01      4  163475
# 90 2021-11-01      3  175322
# 91 2021-12-01      1  326143
# 92 2021-12-01      2   18569
# 93 2021-12-01      4  394933
# 94 2021-12-01      3  544276

# %%
# now working with the state_vax.csv dataframe

keep_state = ["NY", "CA", "FL", "IL"]
vax_df = df.loc[df["state"].isin(keep_state)]


# df_4state_m = df_4state.set_index("date")
# df_4state_m = df_4state_m.groupby(df_4state_m.index.strftime("%Y-%m")).tail(1)
# df_4state_m = df_4state_m.reset_index().sort_values(by="date", ascending=True)
# manuf_4state_m = df_4state_m[["date","state", "admin_janssen", "admin_moderna", "admin_pfizer", "admin_unk"]]

# %%
vax_df = vax_df[vax_df["date"].dt.is_month_start].sort_values(by="date", ascending=True)
vax_df = vax_df[["date","state", "admin_janssen", "admin_moderna", "admin_pfizer", "admin_unk"]]


numstate = {"CA":1, "FL":2, "NY":3, "IL":4}
vax_df["state"] = vax_df["state"].replace(numstate)

# %%
# vax_df

# %%
# vax_df.dtypes

# %%
vax_df = vax_df.sort_values(["date", "state"])
vax_df = vax_df.join(vax_df.groupby("state")[["admin_janssen", "admin_moderna", "admin_pfizer", "admin_unk"]].diff().fillna(0), rsuffix="_diff")

# %%
vax_df_diff = vax_df.drop(columns=["admin_janssen", "admin_moderna", "admin_pfizer", "admin_unk"])

# %%
vax_df_diff
# Out:
#             date  state  admin_janssen_diff  admin_moderna_diff  \
# 28402 2021-01-01      1                 0.0                 0.0
# 28443 2021-01-01      2                 0.0                 0.0
# 28451 2021-01-01      3                 0.0                 0.0
# 28440 2021-01-01      4                 0.0                 0.0
# 26418 2021-02-01      1                 0.0           1539751.0
# 26400 2021-02-01      2                 0.0            867328.0
# 26399 2021-02-01      3                 0.0            861108.0
# 26414 2021-02-01      4                 0.0            415968.0
# 24596 2021-03-01      1               352.0           2859867.0
# 24593 2021-03-01      2                 0.0           1537425.0
# 24560 2021-03-01      3                 0.0           1310516.0
# 24571 2021-03-01      4                 0.0            958915.0
# 22559 2021-04-01      1            370149.0           4269462.0
# 22584 2021-04-01      2            242259.0           2104044.0
# 22579 2021-04-01      3            216370.0           2056040.0
# 22566 2021-04-01      4            128349.0           1410282.0
# 20641 2021-05-01      1            731072.0           4850227.0
# 20621 2021-05-01      2            312882.0           2119002.0
# 20595 2021-05-01      3            386725.0           2509322.0
# 20644 2021-05-01      4            183659.0           1257608.0
# 18636 2021-06-01      1            255978.0           2625843.0
# 18625 2021-06-01      2            261220.0           1198238.0
# 18630 2021-06-01      3            224941.0           1332360.0
# 18608 2021-06-01      4             82759.0            704081.0
# 16660 2021-07-01      1            198595.0           1147495.0
# 16653 2021-07-01      2            195740.0            554288.0
# 16676 2021-07-01      3            120755.0            591930.0
# 16659 2021-07-01      4             61836.0            341640.0
# 14620 2021-08-01      1            115222.0            680467.0
# 14652 2021-08-01      2             97267.0            360424.0
# 14610 2021-08-01      3             64769.0            296836.0
# 14619 2021-08-01      4             32683.0            145697.0
# 12625 2021-09-01      1            106021.0            702586.0
# 12607 2021-09-01      2             60293.0            696581.0
# 12597 2021-09-01      3             58745.0            316637.0
# 12599 2021-09-01      4             41461.0            169286.0
# 10688 2021-10-01      1             81557.0            668299.0
# 10661 2021-10-01      2             35483.0            543660.0
# 10665 2021-10-01      3             54984.0            338420.0
# 10662 2021-10-01      4             20101.0            138630.0
# 8641  2021-11-01      1             85671.0            939535.0
# 8658  2021-11-01      2             44977.0            523555.0
# 8700  2021-11-01      3             52557.0            395012.0
# 8668  2021-11-01      4             15536.0            241753.0
# 6775  2021-12-01      1            139626.0           2299734.0
# 6727  2021-12-01      2             79019.0           1030470.0
# 6740  2021-12-01      3             65715.0            955656.0
# 6732  2021-12-01      4             46635.0            720582.0
# 4799  2022-01-01      1            120769.0           2459492.0
# 4750  2022-01-01      2             67534.0            961112.0
# 4797  2022-01-01      3            102809.0           1607181.0
# 4781  2022-01-01      4             33983.0            635836.0
# 2797  2022-02-01      1             31643.0           1021664.0
# 2761  2022-02-01      2             36748.0            525365.0
# 2806  2022-02-01      3             43500.0            715648.0
# 2780  2022-02-01      4             22980.0            460405.0
# 1014  2022-03-01      1             40607.0            624395.0
# 1004  2022-03-01      2             23281.0            224731.0
# 1017  2022-03-01      3             25211.0            323256.0
# 960   2022-03-01      4              3714.0             69746.0
#
#        admin_pfizer_diff  admin_unk_diff
# 28402                0.0             0.0
# 28443                0.0             0.0
# 28451                0.0             0.0
# 28440                0.0             0.0
# 26418          1539036.0             0.0
# 26400           898940.0          1301.0
# 26399           837858.0           200.0
# 26414           474188.0           185.0
# 24596          2792564.0            10.0
# 24593          1501240.0          3917.0
# 24560          1117118.0           245.0
# 24571           892001.0           825.0
# 22559          4856850.0          1626.0
# 22584          2379069.0          8407.0
# 22579          2764718.0           812.0
# 22566          1626525.0          1708.0
# 20641          6633513.0          1859.0
# 20621          3262918.0         11564.0
# 20595          3567394.0          1674.0
# 20644          2034106.0          2477.0
# 18636          4768392.0          1681.0
# 18625          1862554.0         11180.0
# 18630          2290258.0          1220.0
# 18608          1360702.0          2658.0
# 16660          2951158.0          1708.0
# 16653          1529461.0         12304.0
# 16676          1430009.0           952.0
# 16659           894424.0          2663.0
# 14620          1705282.0          1791.0
# 14652          1038927.0         16986.0
# 14610           783841.0          1371.0
# 14619           498166.0          4297.0
# 12625          2022994.0          3802.0
# 12607          1579815.0         14158.0
# 12597          1054236.0          1424.0
# 12599           771568.0          2584.0
# 10688          1858195.0           768.0
# 10661          1267819.0         13564.0
# 10665          1139914.0          1455.0
# 10662           519956.0          2203.0
# 8641           2693022.0          1348.0
# 8658           1244225.0         11243.0
# 8700           1263019.0          1325.0
# 8668            665108.0          -311.0
# 6775           2889859.0           636.0
# 6727           1237659.0          7871.0
# 6740           1328089.0          1127.0
# 6732            944435.0          5176.0
# 4799           3883027.0           777.0
# 4750           1685045.0          7285.0
# 4797           2765387.0          3935.0
# 4781           1179729.0          1844.0
# 2797           2054707.0         -1485.0
# 2761           1092888.0          6855.0
# 2806           1477651.0          2084.0
# 2780            995726.0          1545.0
# 1014           1589091.0           818.0
# 1004            488597.0          5941.0
# 1017            789996.0          1778.0
# 960             393336.0          1093.0

# %%
# exporting vax_df_diff to csv

# vax_df_diff.to_csv("covid_vax.csv", index=False)

# %%
vax_df_diff.describe(include = 'all', datetime_is_numeric=True)
# Out:
#                       date      state  admin_janssen_diff  admin_moderna_diff  \
# count                   60  60.000000           60.000000        6.000000e+01
# mean   2021-08-01 04:48:00   2.500000        97079.033333        1.020257e+06
# min    2021-01-01 00:00:00   1.000000            0.000000        0.000000e+00
# 25%    2021-04-01 00:00:00   1.750000        22260.250000        3.557280e+05
# 50%    2021-08-01 00:00:00   2.500000        56864.500000        7.033335e+05
# 75%    2021-12-01 00:00:00   3.250000       120758.500000        1.315977e+06
# max    2022-03-01 00:00:00   4.000000       731072.000000        4.850227e+06
# std                    NaN   1.127469       126156.367510        9.795663e+05
#
#        admin_pfizer_diff  admin_unk_diff
# count       6.000000e+01       60.000000
# mean        1.652772e+06     3274.400000
# min         0.000000e+00    -1485.000000
# 25%         8.938182e+05      816.500000
# 50%         1.344396e+06     1677.500000
# 75%         2.039256e+06     3921.500000
# max         6.633513e+06    16986.000000
# std         1.254088e+06     4143.133471

# %%
vax_df_diff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 28402 to 960
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                60 non-null     datetime64[ns]
#  1   state               60 non-null     int64
#  2   admin_janssen_diff  60 non-null     float64
#  3   admin_moderna_diff  60 non-null     float64
#  4   admin_pfizer_diff   60 non-null     float64
#  5   admin_unk_diff      60 non-null     float64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 5.3 KB

# %%
merged_case_vax = pd.merge(cases_df, vax_df_diff, on=["date", "state"], how="inner")

# %%
shiftcol = ["admin_janssen_diff", "admin_moderna_diff", "admin_pfizer_diff", "admin_unk_diff"]
merged_case_vax[shiftcol] = merged_case_vax[shiftcol].shift(4)

# %%
merged_case_vax
# Out:
#          date  state   cases  admin_janssen_diff  admin_moderna_diff  \
# 0  2021-01-01      1  877185                 NaN                 NaN
# 1  2021-01-01      2  207612                 NaN                 NaN
# 2  2021-01-01      4  127099                 NaN                 NaN
# 3  2021-01-01      3  333399                 NaN                 NaN
# 4  2021-02-01      1  182380                 0.0                 0.0
# 5  2021-02-01      2  165000                 0.0                 0.0
# 6  2021-02-01      4   50197                 0.0                 0.0
# 7  2021-02-01      3  199327                 0.0                 0.0
# 8  2021-03-01      1   83365                 0.0           1539751.0
# 9  2021-03-01      2  330204                 0.0            867328.0
# 10 2021-03-01      4   70218                 0.0            415968.0
# 11 2021-03-01      3  222687                 0.0            861108.0
# 12 2021-04-01      1   65972               352.0           2859867.0
# 13 2021-04-01      2  111786                 0.0           1537425.0
# 14 2021-04-01      4   81205                 0.0            958915.0
# 15 2021-04-01      3  144255                 0.0           1310516.0
# 16 2021-05-01      1   38232            370149.0           4269462.0
# 17 2021-05-01      2   54597            242259.0           2104044.0
# 18 2021-05-01      4   31940            128349.0           1410282.0
# 19 2021-05-01      3   42055            216370.0           2056040.0
# 20 2021-06-01      1   35709            731072.0           4850227.0
# 21 2021-06-01      2   49974            312882.0           2119002.0
# 22 2021-06-01      4    9547            183659.0           1257608.0
# 23 2021-06-01      3   12562            386725.0           2509322.0
# 24 2021-07-01      1  203143            255978.0           2625843.0
# 25 2021-07-01      2  115593            261220.0           1198238.0
# 26 2021-07-01      4   49716             82759.0            704081.0
# 27 2021-07-01      3   47079            224941.0           1332360.0
# 28 2021-08-01      1  414353            198595.0           1147495.0
# 29 2021-08-01      2  268491            195740.0            554288.0
# 30 2021-08-01      4  115425             61836.0            341640.0
# 31 2021-08-01      3  125079            120755.0            591930.0
# 32 2021-09-01      1  251191            115222.0            680467.0
# 33 2021-09-01      2  287957             97267.0            360424.0
# 34 2021-09-01      4   90863             32683.0            145697.0
# 35 2021-09-01      3  138688             64769.0            296836.0
# 36 2021-10-01      1  178486            106021.0            702586.0
# 37 2021-10-01      2  183619             60293.0            696581.0
# 38 2021-10-01      4   74841             41461.0            169286.0
# 39 2021-10-01      3  117439             58745.0            316637.0
# 40 2021-11-01      1  163753             81557.0            668299.0
# 41 2021-11-01      2   46151             35483.0            543660.0
# 42 2021-11-01      4  163475             20101.0            138630.0
# 43 2021-11-01      3  175322             54984.0            338420.0
# 44 2021-12-01      1  326143             85671.0            939535.0
# 45 2021-12-01      2   18569             44977.0            523555.0
# 46 2021-12-01      4  394933             15536.0            241753.0
# 47 2021-12-01      3  544276             52557.0            395012.0
#
#     admin_pfizer_diff  admin_unk_diff
# 0                 NaN             NaN
# 1                 NaN             NaN
# 2                 NaN             NaN
# 3                 NaN             NaN
# 4                 0.0             0.0
# 5                 0.0             0.0
# 6                 0.0             0.0
# 7                 0.0             0.0
# 8           1539036.0             0.0
# 9            898940.0          1301.0
# 10           474188.0           185.0
# 11           837858.0           200.0
# 12          2792564.0            10.0
# 13          1501240.0          3917.0
# 14           892001.0           825.0
# 15          1117118.0           245.0
# 16          4856850.0          1626.0
# 17          2379069.0          8407.0
# 18          1626525.0          1708.0
# 19          2764718.0           812.0
# 20          6633513.0          1859.0
# 21          3262918.0         11564.0
# 22          2034106.0          2477.0
# 23          3567394.0          1674.0
# 24          4768392.0          1681.0
# 25          1862554.0         11180.0
# 26          1360702.0          2658.0
# 27          2290258.0          1220.0
# 28          2951158.0          1708.0
# 29          1529461.0         12304.0
# 30           894424.0          2663.0
# 31          1430009.0           952.0
# 32          1705282.0          1791.0
# 33          1038927.0         16986.0
# 34           498166.0          4297.0
# 35           783841.0          1371.0
# 36          2022994.0          3802.0
# 37          1579815.0         14158.0
# 38           771568.0          2584.0
# 39          1054236.0          1424.0
# 40          1858195.0           768.0
# 41          1267819.0         13564.0
# 42           519956.0          2203.0
# 43          1139914.0          1455.0
# 44          2693022.0          1348.0
# 45          1244225.0         11243.0
# 46           665108.0          -311.0
# 47          1263019.0          1325.0

# %%
corr = merged_case_vax.corr()
corr
# Out:
#                        state     cases  admin_janssen_diff  \
# state               1.000000 -0.264361           -0.302399
# cases              -0.264361  1.000000           -0.250877
# admin_janssen_diff -0.302399 -0.250877            1.000000
# admin_moderna_diff -0.421932 -0.341484            0.784740
# admin_pfizer_diff  -0.503819 -0.183563            0.874569
# admin_unk_diff     -0.180369 -0.051162            0.147303
#
#                     admin_moderna_diff  admin_pfizer_diff  admin_unk_diff
# state                        -0.421932          -0.503819       -0.180369
# cases                        -0.341484          -0.183563       -0.051162
# admin_janssen_diff            0.784740           0.874569        0.147303
# admin_moderna_diff            1.000000           0.917744       -0.048625
# admin_pfizer_diff             0.917744           1.000000        0.041425
# admin_unk_diff               -0.048625           0.041425        1.000000

# %%
corr_state = merged_case_vax.groupby("state").corr()
corr_state
# Out:
#                              cases  admin_janssen_diff  admin_moderna_diff  \
# state
# 1     cases               1.000000           -0.304657           -0.628733
#       admin_janssen_diff -0.304657            1.000000            0.788978
#       admin_moderna_diff -0.628733            0.788978            1.000000
#       admin_pfizer_diff  -0.320532            0.893908            0.902387
#       admin_unk_diff      0.218443            0.385772            0.062842
# 2     cases               1.000000           -0.255071           -0.429288
#       admin_janssen_diff -0.255071            1.000000            0.632117
#       admin_moderna_diff -0.429288            0.632117            1.000000
#       admin_pfizer_diff  -0.447282            0.815641            0.867792
#       admin_unk_diff     -0.117227            0.401374           -0.028690
# 3     cases               1.000000           -0.549299           -0.538941
#       admin_janssen_diff -0.549299            1.000000            0.806851
#       admin_moderna_diff -0.538941            0.806851            1.000000
#       admin_pfizer_diff  -0.480986            0.945125            0.908624
#       admin_unk_diff     -0.086253            0.550262            0.152306
# 4     cases               1.000000           -0.411668           -0.415706
#       admin_janssen_diff -0.411668            1.000000            0.735432
#       admin_moderna_diff -0.415706            0.735432            1.000000
#       admin_pfizer_diff  -0.331937            0.920821            0.877715
#       admin_unk_diff     -0.378712            0.418598            0.047005
#
#                           admin_pfizer_diff  admin_unk_diff
# state
# 1     cases                       -0.320532        0.218443
#       admin_janssen_diff           0.893908        0.385772
#       admin_moderna_diff           0.902387        0.062842
#       admin_pfizer_diff            1.000000        0.329898
#       admin_unk_diff               0.329898        1.000000
# 2     cases                       -0.447282       -0.117227
#       admin_janssen_diff           0.815641        0.401374
#       admin_moderna_diff           0.867792       -0.028690
#       admin_pfizer_diff            1.000000        0.394048
#       admin_unk_diff               0.394048        1.000000
# 3     cases                       -0.480986       -0.086253
#       admin_janssen_diff           0.945125        0.550262
#       admin_moderna_diff           0.908624        0.152306
#       admin_pfizer_diff            1.000000        0.502141
#       admin_unk_diff               0.502141        1.000000
# 4     cases                       -0.331937       -0.378712
#       admin_janssen_diff           0.920821        0.418598
#       admin_moderna_diff           0.877715        0.047005
#       admin_pfizer_diff            1.000000        0.318716
#       admin_unk_diff               0.318716        1.000000

# %%
formula1 = 'cases ~ admin_janssen_diff + admin_moderna_diff + admin_pfizer_diff + admin_unk_diff'
model1 = sm.ols(formula = formula1, data = merged_case_vax)
fitted1 = model1.fit()
print(fitted1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  cases   R-squared:                       0.284
# Model:                            OLS   Adj. R-squared:                  0.211
# Method:                 Least Squares   F-statistic:                     3.876
# Date:                Wed, 16 Mar 2022   Prob (F-statistic):            0.00959
# Time:                        18:24:22   Log-Likelihood:                -568.88
# No. Observations:                  44   AIC:                             1148.
# Df Residuals:                      39   BIC:                             1157.
# Df Model:                           4
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept           1.451e+05   3.12e+04      4.651      0.000     8.2e+04    2.08e+05
# admin_janssen_diff    -0.3572      0.240     -1.491      0.144      -0.842       0.128
# admin_moderna_diff    -0.1335      0.039     -3.431      0.001      -0.212      -0.055
# admin_pfizer_diff      0.1138      0.038      2.960      0.005       0.036       0.192
# admin_unk_diff        -2.6242      3.727     -0.704      0.485     -10.162       4.914
# ==============================================================================
# Omnibus:                       12.577   Durbin-Watson:                   1.590
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               12.825
# Skew:                           1.137   Prob(JB):                      0.00164
# Kurtosis:                       4.352   Cond. No.                     5.10e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.1e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# p values
fitted1.pvalues
# Out:
# Intercept             0.000037
# admin_janssen_diff    0.144109
# admin_moderna_diff    0.001434
# admin_pfizer_diff     0.005218
# admin_unk_diff        0.485498
# dtype: float64

# %%
formula2 = 'cases ~ admin_janssen_diff + admin_moderna_diff + admin_pfizer_diff'
model2 = sm.ols(formula = formula2, data = merged_case_vax)
fitted2 = model2.fit()
print(fitted2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  cases   R-squared:                       0.275
# Model:                            OLS   Adj. R-squared:                  0.221
# Method:                 Least Squares   F-statistic:                     5.066
# Date:                Wed, 16 Mar 2022   Prob (F-statistic):            0.00456
# Time:                        18:24:22   Log-Likelihood:                -569.16
# No. Observations:                  44   AIC:                             1146.
# Df Residuals:                      40   BIC:                             1153.
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept           1.362e+05   2.83e+04      4.807      0.000    7.89e+04    1.93e+05
# admin_janssen_diff    -0.3935      0.233     -1.692      0.098      -0.863       0.076
# admin_moderna_diff    -0.1280      0.038     -3.380      0.002      -0.204      -0.051
# admin_pfizer_diff      0.1128      0.038      2.953      0.005       0.036       0.190
# ==============================================================================
# Omnibus:                       13.196   Durbin-Watson:                   1.580
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.040
# Skew:                           1.127   Prob(JB):                     0.000894
# Kurtosis:                       4.605   Cond. No.                     4.66e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.66e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
fitted2.pvalues
# Out:
# Intercept             0.000022
# admin_janssen_diff    0.098402
# admin_moderna_diff    0.001630
# admin_pfizer_diff     0.005249
# dtype: float64

# %%
formula3 = 'cases ~ admin_moderna_diff + admin_pfizer_diff'
model3 = sm.ols(formula = formula3, data = merged_case_vax)
fitted3 = model3.fit()
print(fitted3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  cases   R-squared:                       0.223
# Model:                            OLS   Adj. R-squared:                  0.186
# Method:                 Least Squares   F-statistic:                     5.899
# Date:                Wed, 16 Mar 2022   Prob (F-statistic):            0.00560
# Time:                        18:24:22   Log-Likelihood:                -570.68
# No. Observations:                  44   AIC:                             1147.
# Df Residuals:                      41   BIC:                             1153.
# Df Model:                           2
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept           1.542e+05   2.68e+04      5.744      0.000       1e+05    2.08e+05
# admin_moderna_diff    -0.1220      0.039     -3.165      0.003      -0.200      -0.044
# admin_pfizer_diff      0.0723      0.030      2.375      0.022       0.011       0.134
# ==============================================================================
# Omnibus:                       12.892   Durbin-Watson:                   1.490
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               13.444
# Skew:                           1.127   Prob(JB):                      0.00120
# Kurtosis:                       4.502   Cond. No.                     4.31e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.31e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
fitted3.pvalues
# Out:
# Intercept             0.000001
# admin_moderna_diff    0.002919
# admin_pfizer_diff     0.022294
# dtype: float64

# %%
moderna_cases = 'cases ~ admin_moderna_diff'
moderna_model = sm.ols(formula = moderna_cases, data = merged_case_vax)
moderna_fit = moderna_model.fit()
print(moderna_fit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  cases   R-squared:                       0.117
# Model:                            OLS   Adj. R-squared:                  0.096
# Method:                 Least Squares   F-statistic:                     5.544
# Date:                Wed, 16 Mar 2022   Prob (F-statistic):             0.0233
# Time:                        18:24:22   Log-Likelihood:                -573.52
# No. Observations:                  44   AIC:                             1151.
# Df Residuals:                      42   BIC:                             1155.
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept           1.874e+05   2.42e+04      7.754      0.000    1.39e+05    2.36e+05
# admin_moderna_diff    -0.0380      0.016     -2.355      0.023      -0.071      -0.005
# ==============================================================================
# Omnibus:                       15.922   Durbin-Watson:                   1.664
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.195
# Skew:                           1.324   Prob(JB):                     0.000112
# Kurtosis:                       4.707   Cond. No.                     2.12e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.12e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
pfizer_cases = 'cases ~ admin_pfizer_diff'
pfizer_model = sm.ols(formula = pfizer_cases, data = merged_case_vax)
pfizer_fit = pfizer_model.fit()
print(pfizer_fit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  cases   R-squared:                       0.034
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     1.465
# Date:                Wed, 16 Mar 2022   Prob (F-statistic):              0.233
# Time:                        18:24:22   Log-Likelihood:                -575.49
# No. Observations:                  44   AIC:                             1155.
# Df Residuals:                      42   BIC:                             1159.
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept          1.744e+05   2.87e+04      6.068      0.000    1.16e+05    2.32e+05
# admin_pfizer_diff    -0.0161      0.013     -1.210      0.233      -0.043       0.011
# ==============================================================================
# Omnibus:                       17.221   Durbin-Watson:                   1.546
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.376
# Skew:                           1.414   Prob(JB):                     3.76e-05
# Kurtosis:                       4.765   Cond. No.                     3.47e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.47e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Analyzing Demographics

# %% [markdown]
# Age Group, Gender, Race/Ethnicity

# %% [markdown]
# #### Age Group

# %% [markdown]
# #### Gender

# %% [markdown]
# **CA**
#
# https://data.chhs.ca.gov/dataset/vaccine-progress-dashboard/resource/faee36da-bd8c-40f7-96d4-d8f283a12b0a?inner_span=True&filters=demographic_category%3AGender

# %%
ca_gender = pd.read_csv("data/ca_gender.csv")

# %%
ca_gender = ca_gender.drop(columns=["demographic_category", "booster_recip_count", "cumulative_booster_recip_count", 
                                   "cumulative_total_doses", "cumulative_pfizer_doses", "cumulative_moderna_doses", 
                                   "cumulative_jj_doses", "total_partially_vaccinated", "cumulative_fully_vaccinated", 
                                   "cumulative_at_least_one_dose"])
ca_gender = ca_gender.rename(columns={"administered_date" : "date"})

# %%
ca_gender["demographic_value"].unique()
# Out:
# array(['Male', 'Female', 'Unknown/undifferentiated'], dtype=object)

# %%
ca_gender = ca_gender[~ca_gender["demographic_value"].isin(["Unknown/undifferentiated"])]

# %%
ca_gender["date"] = pd.to_datetime(ca_gender["date"])

# %%
ca_gender = ca_gender[ca_gender["date"].dt.is_month_start].sort_values(by="date", ascending=True)

# %%
# ca_gender

# %%
ca_dup = ca_gender[ca_gender.duplicated(["date"], keep=False)].copy()

# %%
ca_bothgender = ca_dup.groupby("date")["pfizer_doses", "moderna_doses", "jj_doses"].apply(lambda x: x.sum())
# Out:
# <ipython-input-293-216bba762532>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   ca_bothgender = ca_dup.groupby("date")["pfizer_doses", "moderna_doses", "jj_doses"].apply(lambda x: x.sum())

# %%
ca_bothgender = ca_bothgender.rename(columns={"pfizer_doses":"pfizer_both",
                                              "moderna_doses" : "moderna_both",
                                              "jj_doses" : "jj_both"}).reset_index()

# %%
# ca_bothgender

# %%
ca_gender = pd.merge(ca_gender, ca_bothgender, on="date", how="inner")

# %%
# ca_gender

# %%
ca_gender["pfizer_malepct"] = ca_gender.loc[ca_gender["demographic_value"] == "Male", "pfizer_doses"] / ca_gender["pfizer_both"]

# %%
ca_gender["moderna_malepct"] = ca_gender.loc[ca_gender["demographic_value"] == "Male", "moderna_doses"] / ca_gender["moderna_both"]

# %%
ca_gender["jj_malepct"] = ca_gender.loc[ca_gender["demographic_value"] == "Male", "jj_doses"] / ca_gender["jj_both"]

# %%
ca_gender["pfizer_femalepct"] = ca_gender.loc[ca_gender["demographic_value"] == "Female", "pfizer_doses"] / ca_gender["pfizer_both"]

# %%
ca_gender["moderna_femalepct"] = ca_gender.loc[ca_gender["demographic_value"] == "Female", "moderna_doses"] / ca_gender["moderna_both"]

# %%
ca_gender["jj_femalepct"] = ca_gender.loc[ca_gender["demographic_value"] == "Female", "jj_doses"] / ca_gender["jj_both"]

# %%
# creating a new df to use percentages of each gender demo with the covid case data and vax data 

ca_genderpct = ca_gender[["date","pfizer_malepct", "moderna_malepct", "jj_malepct", "pfizer_femalepct", "moderna_femalepct", "jj_femalepct"]]

# %%
ca_genderpct = ca_genderpct.groupby("date").agg({"pfizer_malepct" : "first", "moderna_malepct" : "first",
                                                              "jj_malepct" : "first", "pfizer_femalepct" : "first", 
                                                              "moderna_femalepct" : "first", "jj_femalepct" : "first"}).fillna(0).reset_index()

# %%
# ca_genderpct

# %%
# filtering vax df and covid case df for CA

# %%
covid_gender = covid_df[covid_df["state"].isin(["CA"])]

# %%
covid_gender = covid_gender[~covid_gender["sex"].isin(["Not Available"])]

# %%
covid_gender = covid_gender.groupby(["date", "sex"]).size().reset_index(name="cases")

# %%
# covid_gender

# %%
case_gender = covid_gender.pivot(index="date", columns="sex", values="cases").reset_index().rename_axis(None, axis=1)

# %%
case_gender["case_tot"] = case_gender["Female"] + case_gender["Male"]

case_gender = case_gender.rename(columns={"Female" : "cases_female", "Male" : "cases_male"})

# %%
# remerge vax df with new case_gender

# %%
ca_vax_diff = vax_df_diff[vax_df_diff["state"].isin([1])]

# %%
ca_case_vax = pd.merge(case_gender, ca_vax_diff, on=["date"], how="inner" )

# %%
# need to shift the vax numbers as we did before
shiftcol = ["admin_janssen_diff", "admin_moderna_diff", "admin_pfizer_diff", "admin_unk_diff"]
ca_case_vax[shiftcol] = ca_case_vax[shiftcol].shift(1)

# %%
ca_covidgen =  pd.merge(ca_case_vax, ca_genderpct, on=["date"], how="inner")

# %%
# we are making the assumption that there is no preference on which vaccine manufacturer is administered 

# male cols
ca_covidgen["admin_janssen_male"] = (ca_covidgen["admin_janssen_diff"] * ca_covidgen["jj_malepct"]).round()

ca_covidgen["admin_moderna_male"] = (ca_covidgen["admin_moderna_diff"] * ca_covidgen["moderna_malepct"]).round()

ca_covidgen["admin_pfizer_male"] = (ca_covidgen["admin_pfizer_diff"] * ca_covidgen["pfizer_malepct"]).round()

# female cols
ca_covidgen["admin_janssen_female"] = (ca_covidgen["admin_janssen_diff"] * ca_covidgen["jj_femalepct"]).round()

ca_covidgen["admin_moderna_female"] = (ca_covidgen["admin_moderna_diff"] * ca_covidgen["moderna_femalepct"]).round()

ca_covidgen["admin_pfizer_female"] = (ca_covidgen["admin_pfizer_diff"] * ca_covidgen["pfizer_femalepct"]).round()

# %%
ca_covidgen
# Out:
#          date  cases_female  cases_male  case_tot  state  admin_janssen_diff  \
# 0  2021-01-01        444099      416152    860251      1                 NaN
# 1  2021-02-01         90725       88556    179281      1                 0.0
# 2  2021-03-01         40960       40596     81556      1                 0.0
# 3  2021-04-01         32799       31611     64410      1               352.0
# 4  2021-05-01         19084       17779     36863      1            370149.0
# 5  2021-06-01         17639       16652     34291      1            731072.0
# 6  2021-07-01        102884       96959    199843      1            255978.0
# 7  2021-08-01        207631      197718    405349      1            198595.0
# 8  2021-09-01        125332      120407    245739      1            115222.0
# 9  2021-10-01         89587       84546    174133      1            106021.0
# 10 2021-11-01         82027       77829    159856      1             81557.0
# 11 2021-12-01        167106      151341    318447      1             85671.0
#
#     admin_moderna_diff  admin_pfizer_diff  admin_unk_diff  pfizer_malepct  \
# 0                  NaN                NaN             NaN        0.430412
# 1                  0.0                0.0             0.0        0.401580
# 2            1539751.0          1539036.0             0.0        0.435514
# 3            2859867.0          2792564.0            10.0        0.479150
# 4            4269462.0          4856850.0          1626.0        0.501734
# 5            4850227.0          6633513.0          1859.0        0.493341
# 6            2625843.0          4768392.0          1681.0        0.478236
# 7            1147495.0          2951158.0          1708.0        0.509855
# 8             680467.0          1705282.0          1791.0        0.479664
# 9             702586.0          2022994.0          3802.0        0.433021
# 10            668299.0          1858195.0           768.0        0.462795
# 11            939535.0          2693022.0          1348.0        0.471866
#
#     ...  jj_malepct  pfizer_femalepct  moderna_femalepct  jj_femalepct  \
# 0   ...    0.560284          0.569588           0.564265      0.439716
# 1   ...    0.539130          0.598420           0.563364      0.460870
# 2   ...    0.484914          0.564486           0.561395      0.515086
# 3   ...    0.516532          0.520850           0.526763      0.483468
# 4   ...    0.622582          0.498266           0.491461      0.377418
# 5   ...    0.655199          0.506659           0.482667      0.344801
# 6   ...    0.631365          0.521764           0.491262      0.368635
# 7   ...    0.616745          0.490145           0.449309      0.383255
# 8   ...    0.612239          0.520336           0.492171      0.387761
# 9   ...    0.596899          0.566979           0.519711      0.403101
# 10  ...    0.555050          0.537205           0.537857      0.444950
# 11  ...    0.569164          0.528134           0.520152      0.430836
#
#     admin_janssen_male  admin_moderna_male  admin_pfizer_male  \
# 0                  NaN                 NaN                NaN
# 1                  0.0                 0.0                0.0
# 2                  0.0            675342.0           670271.0
# 3                182.0           1353396.0          1338058.0
# 4             230448.0           2171187.0          2436846.0
# 5             478998.0           2509180.0          3272583.0
# 6             161616.0           1335867.0          2280415.0
# 7             122483.0            631915.0          1504662.0
# 8              70543.0            345561.0           817963.0
# 9              63284.0            337444.0           875999.0
# 10             45268.0            308850.0           859963.0
# 11             48761.0            450834.0          1270746.0
#
#     admin_janssen_female  admin_moderna_female  admin_pfizer_female
# 0                    NaN                   NaN                  NaN
# 1                    0.0                   0.0                  0.0
# 2                    0.0              864409.0             868765.0
# 3                  170.0             1506471.0            1454506.0
# 4               139701.0             2098275.0            2420004.0
# 5               252074.0             2341047.0            3360930.0
# 6                94362.0             1289976.0            2487977.0
# 7                76112.0              515580.0            1446496.0
# 8                44679.0              334906.0             887319.0
# 9                42737.0              365142.0            1146995.0
# 10               36289.0              359449.0             998232.0
# 11               36910.0              488701.0            1422276.0
#
# [12 rows x 21 columns]

# %%
ca_covidgen.plot(x="date", y=["admin_janssen_male", "admin_moderna_male", "admin_pfizer_male",
                              "admin_janssen_female", "admin_moderna_female", "admin_pfizer_female"], kind="line", title="Rates of Vaccine Administration by Manufacturer and Sex in CA")
# Out:
# <AxesSubplot:title={'center':'Rates of Vaccine Administration by Manufacturer and Sex in CA'}, xlabel='date'>

# %%
ca_covidgen.plot(x="date", y=["admin_janssen_male", "admin_moderna_male", "admin_pfizer_male",
                              "cases_male"], kind="line", title="Male Vaccine Administration by Manufacturer vs. Cases in CA")
# Out:
# <AxesSubplot:title={'center':'Male Vaccine Administration by Manufacturer vs. Cases in CA'}, xlabel='date'>

# %%
ca_covidgen.plot(x="date", y=["admin_janssen_female", "admin_moderna_female", "admin_pfizer_female",
                              "cases_female"], kind="line", title="Female Vaccine Administration by Manufacturer vs. Cases in CA")
# Out:
# <AxesSubplot:title={'center':'Female Vaccine Administration by Manufacturer vs. Cases in CA'}, xlabel='date'>

# %%
ca_covidgen.plot(x="date", y=["cases_male", "cases_female", "case_tot"], kind="line", title="Rate of COVID Cases by Gender in CA")
# Out:
# <AxesSubplot:title={'center':'Rate of COVID Cases by Gender in CA'}, xlabel='date'>

# %%
# LINEAR REGRESSIONS FOR CASES GENDER

caf_formula = "cases_female ~ admin_janssen_female + admin_moderna_female + admin_pfizer_female"
caf_model = sm.ols(formula=caf_formula, data = ca_covidgen)
caf_fitted = caf_model.fit()

print(caf_fitted.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           cases_female   R-squared:                       0.709
# Model:                            OLS   Adj. R-squared:                  0.585
# Method:                 Least Squares   F-statistic:                     5.691
# Date:                Wed, 16 Mar 2022   Prob (F-statistic):             0.0271
# Time:                        19:22:59   Log-Likelihood:                -129.49
# No. Observations:                  11   AIC:                             267.0
# Df Residuals:                       7   BIC:                             268.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept             9.049e+04   2.88e+04      3.140      0.016    2.23e+04    1.59e+05
# admin_janssen_female    -0.1793      0.363     -0.494      0.636      -1.037       0.678
# admin_moderna_female    -0.1289      0.034     -3.812      0.007      -0.209      -0.049
# admin_pfizer_female      0.0861      0.041      2.115      0.072      -0.010       0.182
# ==============================================================================
# Omnibus:                        2.847   Durbin-Watson:                   1.973
# Prob(Omnibus):                  0.241   Jarque-Bera (JB):                0.894
# Skew:                           0.676   Prob(JB):                        0.640
# Kurtosis:                       3.350   Cond. No.                     5.08e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.08e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Users/austinwahl/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=11
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %%
cam_formula = "cases_male ~ admin_janssen_male + admin_moderna_male + admin_pfizer_male"
cam_model = sm.ols(formula=cam_formula, data = ca_covidgen)
cam_fitted = cam_model.fit()

print(cam_fitted.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             cases_male   R-squared:                       0.767
# Model:                            OLS   Adj. R-squared:                  0.666
# Method:                 Least Squares   F-statistic:                     7.661
# Date:                Wed, 16 Mar 2022   Prob (F-statistic):             0.0129
# Time:                        19:22:59   Log-Likelihood:                -127.56
# No. Observations:                  11   AIC:                             263.1
# Df Residuals:                       7   BIC:                             264.7
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept           7.301e+04   2.37e+04      3.080      0.018     1.7e+04    1.29e+05
# admin_janssen_male    -0.1041      0.167     -0.624      0.552      -0.499       0.290
# admin_moderna_male    -0.1467      0.033     -4.447      0.003      -0.225      -0.069
# admin_pfizer_male      0.1131      0.037      3.026      0.019       0.025       0.201
# ==============================================================================
# Omnibus:                        2.277   Durbin-Watson:                   1.927
# Prob(Omnibus):                  0.320   Jarque-Bera (JB):                0.577
# Skew:                           0.535   Prob(JB):                        0.749
# Kurtosis:                       3.335   Cond. No.                     4.86e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.86e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Users/austinwahl/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=11
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %% [markdown]
# **FL, IL, NY**
#
# No data for gender administration over time, applying the most recent percentages from each state's health department website.
#
# {"CA":1, "FL":2, "NY":3, "IL":4}
#
# http://ww11.doh.state.fl.us/comm/_partners/covid19_report_archive/covid19-data/covid19_data_latest.pdf
#
# https://dph.illinois.gov/covid19/vaccine/vaccine-data.html?county=Illinois#demographics
#
# https://coronavirus.health.ny.gov/demographic-vaccination-data

# %% [markdown]
# Florida:

# %%
fl_vax = vax_df_diff[vax_df_diff["state"].isin([2])]

# %%
# fl_vax

# %%
fl_case = covid_df[covid_df["state"].isin(["FL"])]

fl_case = fl_case[~fl_case["sex"].isin(["Not Available"])]

fl_case = fl_case.groupby(["date", "sex"]).size().reset_index(name="cases")

# %%
# fl_case

# %%
fl_casegen = fl_case.pivot(index="date", columns="sex", values="cases").reset_index().rename_axis(None, axis=1).fillna(0)

# %%
fl_casegen["case_tot"] = fl_casegen["Female"] + fl_casegen["Male"]

fl_casegen = fl_casegen.rename(columns={"Female" : "cases_female", "Male" : "cases_male"})

# %%
# fl_casegen

# %%
# merge of cases and vax
fl_case_vax = pd.merge(fl_casegen, fl_vax, on=["date"], how="inner")

# %%
# need to shift the vax numbers as we did before
shiftcol = ["admin_janssen_diff", "admin_moderna_diff", "admin_pfizer_diff", "admin_unk_diff"]
fl_case_vax[shiftcol] = fl_case_vax[shiftcol].shift(1)

# %%
# fl_case_vax

# %%
# applying % vaccinated per gender group

fl_case_vax["admin_janssen_male"] = (fl_case_vax["admin_janssen_diff"] * 0.46547053).round()

fl_case_vax["admin_moderna_male"] = (fl_case_vax["admin_moderna_diff"] * 0.46547053).round()

fl_case_vax["admin_pfizer_male"] = (fl_case_vax["admin_pfizer_diff"] * 0.46547053).round()

# female cols
fl_case_vax["admin_janssen_female"] = (fl_case_vax["admin_janssen_diff"] * 0.53278872).round()

fl_case_vax["admin_moderna_female"] = (fl_case_vax["admin_moderna_diff"] * 0.53278872).round()

fl_case_vax["admin_pfizer_female"] = (fl_case_vax["admin_pfizer_diff"] * 0.53278872).round()

# %%
fl_case_vax
# Out:
#          date  cases_female  cases_male  case_tot  state  admin_janssen_diff  \
# 0  2021-01-01      109341.0     95975.0  205316.0      2                 NaN
# 1  2021-02-01       85760.0     76786.0  162546.0      2                 0.0
# 2  2021-03-01      171793.0    154809.0  326602.0      2                 0.0
# 3  2021-04-01       57955.0     51480.0  109435.0      2                 0.0
# 4  2021-05-01       28271.0     24586.0   52857.0      2            242259.0
# 5  2021-06-01       25574.0     22576.0   48150.0      2            312882.0
# 6  2021-07-01       61034.0     51898.0  112932.0      2            261220.0
# 7  2021-08-01      140509.0    122508.0  263017.0      2            195740.0
# 8  2021-09-01      147723.0    134000.0  281723.0      2             97267.0
# 9  2021-10-01       92991.0     85730.0  178721.0      2             60293.0
# 10 2021-11-01       22884.0     21196.0   44080.0      2             35483.0
# 11 2021-12-01        9035.0      8032.0   17067.0      2             44977.0
#
#     admin_moderna_diff  admin_pfizer_diff  admin_unk_diff  admin_janssen_male  \
# 0                  NaN                NaN             NaN                 NaN
# 1                  0.0                0.0             0.0                 0.0
# 2             867328.0           898940.0          1301.0                 0.0
# 3            1537425.0          1501240.0          3917.0                 0.0
# 4            2104044.0          2379069.0          8407.0            112764.0
# 5            2119002.0          3262918.0         11564.0            145637.0
# 6            1198238.0          1862554.0         11180.0            121590.0
# 7             554288.0          1529461.0         12304.0             91111.0
# 8             360424.0          1038927.0         16986.0             45275.0
# 9             696581.0          1579815.0         14158.0             28065.0
# 10            543660.0          1267819.0         13564.0             16516.0
# 11            523555.0          1244225.0         11243.0             20935.0
#
#     admin_moderna_male  admin_pfizer_male  admin_janssen_female  \
# 0                  NaN                NaN                   NaN
# 1                  0.0                0.0                   0.0
# 2             403716.0           418430.0                   0.0
# 3             715626.0           698783.0                   0.0
# 4             979370.0          1107387.0              129073.0
# 5             986333.0          1518792.0              166700.0
# 6             557744.0           866964.0              139175.0
# 7             258005.0           711919.0              104288.0
# 8             167767.0           483590.0               51823.0
# 9             324238.0           735357.0               32123.0
# 10            253058.0           590132.0               18905.0
# 11            243699.0           579150.0               23963.0
#
#     admin_moderna_female  admin_pfizer_female
# 0                    NaN                  NaN
# 1                    0.0                  0.0
# 2               462103.0             478945.0
# 3               819123.0             799844.0
# 4              1121011.0            1267541.0
# 5              1128980.0            1738446.0
# 6               638408.0             992348.0
# 7               295318.0             814880.0
# 8               192030.0             553529.0
# 9               371130.0             841708.0
# 10              289656.0             675480.0
# 11              278944.0             662909.0

# %%
# LINEAR REGRESSIONS FOR CASES GENDER

flf_formula = "cases_female ~ admin_janssen_female + admin_moderna_female + admin_pfizer_female"
flf_model = sm.ols(formula=flf_formula, data =fl_case_vax)
flf_fitted = flf_model.fit()

print(flf_fitted.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           cases_female   R-squared:                       0.239
# Model:                            OLS   Adj. R-squared:                 -0.087
# Method:                 Least Squares   F-statistic:                    0.7324
# Date:                Wed, 16 Mar 2022   Prob (F-statistic):              0.565
# Time:                        19:23:01   Log-Likelihood:                -133.88
# No. Observations:                  11   AIC:                             275.8
# Df Residuals:                       7   BIC:                             277.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept             1.306e+05   4.29e+04      3.045      0.019    2.92e+04    2.32e+05
# admin_janssen_female     0.2981      0.531      0.561      0.592      -0.958       1.554
# admin_moderna_female    -0.0079      0.103     -0.076      0.941      -0.252       0.236
# admin_pfizer_female     -0.0847      0.116     -0.728      0.490      -0.360       0.190
# ==============================================================================
# Omnibus:                        0.610   Durbin-Watson:                   1.602
# Prob(Omnibus):                  0.737   Jarque-Bera (JB):                0.583
# Skew:                           0.244   Prob(JB):                        0.747
# Kurtosis:                       1.984   Cond. No.                     2.65e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.65e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Users/austinwahl/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=11
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %%
flm_formula = "cases_male ~ admin_janssen_male + admin_moderna_male + admin_pfizer_male"
flm_model = sm.ols(formula=flm_formula, data = fl_case_vax)
flm_fitted = flm_model.fit()

print(flm_fitted.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             cases_male   R-squared:                       0.237
# Model:                            OLS   Adj. R-squared:                 -0.090
# Method:                 Least Squares   F-statistic:                    0.7255
# Date:                Wed, 16 Mar 2022   Prob (F-statistic):              0.568
# Time:                        19:23:01   Log-Likelihood:                -132.73
# No. Observations:                  11   AIC:                             273.5
# Df Residuals:                       7   BIC:                             275.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept           1.165e+05   3.86e+04      3.015      0.020    2.51e+04    2.08e+05
# admin_janssen_male     0.2702      0.548      0.494      0.637      -1.024       1.565
# admin_moderna_male    -0.0102      0.106     -0.095      0.927      -0.262       0.242
# admin_pfizer_male     -0.0824      0.120     -0.687      0.514      -0.366       0.201
# ==============================================================================
# Omnibus:                        0.581   Durbin-Watson:                   1.601
# Prob(Omnibus):                  0.748   Jarque-Bera (JB):                0.570
# Skew:                           0.239   Prob(JB):                        0.752
# Kurtosis:                       1.992   Cond. No.                     2.32e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.32e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Users/austinwahl/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=11
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %% [markdown]
# New York:
#
# total vax = 15,773,390

# %%
ny_vax = vax_df_diff[vax_df_diff["state"].isin([3])]

# %%
# ny_vax

# %%
ny_case = covid_df[covid_df["state"].isin(["NY"])]

ny_case = ny_case[~ny_case["sex"].isin(["Not Available"])]

ny_case = ny_case.groupby(["date", "sex"]).size().reset_index(name="cases")

# %%
# ny_case

# %%
ny_casegen = ny_case.pivot(index="date", columns="sex", values="cases").reset_index().rename_axis(None, axis=1).fillna(0)

# %%
ny_casegen["case_tot"] = ny_casegen["Female"] + ny_casegen["Male"]

ny_casegen = ny_casegen.rename(columns={"Female" : "cases_female", "Male" : "cases_male"})

# %%
# ny_casegen

# %%
# merge of cases and vax
ny_case_vax = pd.merge(ny_casegen, ny_vax, on=["date"], how="inner")

# %%
# need to shift the vax numbers as we did before
shiftcol = ["admin_janssen_diff", "admin_moderna_diff", "admin_pfizer_diff", "admin_unk_diff"]
ny_case_vax[shiftcol] = ny_case_vax[shiftcol].shift(1)

# %%
# ny_case_vax

# %%
# applying % vaccinated per gender group

# male = 15,773,390 / 7,494,733 = 0.47515043
# female = 15,773,390 / 8,280,000 = 0.52493472

ny_case_vax["admin_janssen_male"] = (ny_case_vax["admin_janssen_diff"] * 0.47515043).round()

ny_case_vax["admin_moderna_male"] = (ny_case_vax["admin_moderna_diff"] * 0.47515043).round()

ny_case_vax["admin_pfizer_male"] = (ny_case_vax["admin_pfizer_diff"] * 0.47515043).round()

# female cols
ny_case_vax["admin_janssen_female"] = (ny_case_vax["admin_janssen_diff"] * 0.52493472).round()

ny_case_vax["admin_moderna_female"] = (ny_case_vax["admin_moderna_diff"] * 0.52493472).round()

ny_case_vax["admin_pfizer_female"] = (ny_case_vax["admin_pfizer_diff"] * 0.52493472).round()

# %%
ny_case_vax
# Out:
#          date  cases_female  cases_male  case_tot  state  admin_janssen_diff  \
# 0  2021-01-01        169532      158946    328478      3                 NaN
# 1  2021-02-01        101883       94283    196166      3                 0.0
# 2  2021-03-01        113089      106568    219657      3                 0.0
# 3  2021-04-01         74741       67019    141760      3                 0.0
# 4  2021-05-01         21603       18541     40144      3            216370.0
# 5  2021-06-01          6075        5126     11201      3            386725.0
# 6  2021-07-01         23829       21418     45247      3            224941.0
# 7  2021-08-01         66019       57074    123093      3            120755.0
# 8  2021-09-01         71485       64076    135561      3             64769.0
# 9  2021-10-01         60535       53952    114487      3             58745.0
# 10 2021-11-01         90112       82232    172344      3             54984.0
# 11 2021-12-01        284766      252091    536857      3             52557.0
#
#     admin_moderna_diff  admin_pfizer_diff  admin_unk_diff  admin_janssen_male  \
# 0                  NaN                NaN             NaN                 NaN
# 1                  0.0                0.0             0.0                 0.0
# 2             861108.0           837858.0           200.0                 0.0
# 3            1310516.0          1117118.0           245.0                 0.0
# 4            2056040.0          2764718.0           812.0            102808.0
# 5            2509322.0          3567394.0          1674.0            183753.0
# 6            1332360.0          2290258.0          1220.0            106881.0
# 7             591930.0          1430009.0           952.0             57377.0
# 8             296836.0           783841.0          1371.0             30775.0
# 9             316637.0          1054236.0          1424.0             27913.0
# 10            338420.0          1139914.0          1455.0             26126.0
# 11            395012.0          1263019.0          1325.0             24972.0
#
#     admin_moderna_male  admin_pfizer_male  admin_janssen_female  \
# 0                  NaN                NaN                   NaN
# 1                  0.0                0.0                   0.0
# 2             409156.0           398109.0                   0.0
# 3             622692.0           530799.0                   0.0
# 4             976928.0          1313657.0              113580.0
# 5            1192305.0          1695049.0              203005.0
# 6             633071.0          1088217.0              118079.0
# 7             281256.0           679469.0               63388.0
# 8             141042.0           372442.0               33999.0
# 9             150450.0           500921.0               30837.0
# 10            160800.0           541631.0               28863.0
# 11            187690.0           600124.0               27589.0
#
#     admin_moderna_female  admin_pfizer_female
# 0                    NaN                  NaN
# 1                    0.0                  0.0
# 2               452025.0             439821.0
# 3               687935.0             586414.0
# 4              1079287.0            1451296.0
# 5              1317230.0            1872649.0
# 6               699402.0            1202236.0
# 7               310725.0             750661.0
# 8               155820.0             411465.0
# 9               166214.0             553405.0
# 10              177648.0             598380.0
# 11              207356.0             663003.0

# %%
# LINEAR REGRESSIONS FOR CASES GENDER

nyf_formula = "cases_female ~ admin_janssen_female + admin_moderna_female + admin_pfizer_female"
nyf_model = sm.ols(formula=nyf_formula, data =ny_case_vax)
nyf_fitted = nyf_model.fit()

print(nyf_fitted.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           cases_female   R-squared:                       0.461
# Model:                            OLS   Adj. R-squared:                  0.230
# Method:                 Least Squares   F-statistic:                     1.997
# Date:                Wed, 16 Mar 2022   Prob (F-statistic):              0.203
# Time:                        19:23:04   Log-Likelihood:                -135.16
# No. Observations:                  11   AIC:                             278.3
# Df Residuals:                       7   BIC:                             279.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept             6.851e+04   5.37e+04      1.275      0.243   -5.85e+04    1.96e+05
# admin_janssen_female    -1.6177      1.076     -1.503      0.177      -4.163       0.928
# admin_moderna_female    -0.1794      0.128     -1.406      0.203      -0.481       0.122
# admin_pfizer_female      0.2468      0.183      1.345      0.220      -0.187       0.681
# ==============================================================================
# Omnibus:                        8.601   Durbin-Watson:                   1.530
# Prob(Omnibus):                  0.014   Jarque-Bera (JB):                3.897
# Skew:                           1.314   Prob(JB):                        0.143
# Kurtosis:                       4.262   Cond. No.                     3.01e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.01e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Users/austinwahl/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=11
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %%
nym_formula = "cases_male ~ admin_janssen_male + admin_moderna_male + admin_pfizer_male"
nym_model = sm.ols(formula=nym_formula, data = ny_case_vax)
nym_fitted = nym_model.fit()

print(nym_fitted.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             cases_male   R-squared:                       0.463
# Model:                            OLS   Adj. R-squared:                  0.233
# Method:                 Least Squares   F-statistic:                     2.014
# Date:                Wed, 16 Mar 2022   Prob (F-statistic):              0.201
# Time:                        19:23:04   Log-Likelihood:                -133.87
# No. Observations:                  11   AIC:                             275.7
# Df Residuals:                       7   BIC:                             277.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept           6.462e+04   4.78e+04      1.352      0.218   -4.84e+04    1.78e+05
# admin_janssen_male    -1.5672      1.058     -1.481      0.182      -4.069       0.935
# admin_moderna_male    -0.1691      0.125     -1.348      0.220      -0.466       0.128
# admin_pfizer_male      0.2324      0.180      1.289      0.238      -0.194       0.659
# ==============================================================================
# Omnibus:                        8.205   Durbin-Watson:                   1.506
# Prob(Omnibus):                  0.017   Jarque-Bera (JB):                3.680
# Skew:                           1.292   Prob(JB):                        0.159
# Kurtosis:                       4.162   Cond. No.                     2.72e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.72e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Users/austinwahl/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=11
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %% [markdown]
# Illinois:
#
# total vax = 8,979,541

# %%
il_vax = vax_df_diff[vax_df_diff["state"].isin([4])]

# %%
# il_vax

# %%
il_case = covid_df[covid_df["state"].isin(["IL"])]

il_case = il_case[~il_case["sex"].isin(["Not Available"])]

il_case = il_case.groupby(["date", "sex"]).size().reset_index(name="cases")

# %%
# il_case

#Cases for IL aren't reported until 2020-02-01

# %%
il_casegen = il_case.pivot(index="date", columns="sex", values="cases").reset_index().rename_axis(None, axis=1).fillna(0)

# %%
il_casegen["case_tot"] = il_casegen["Female"] + il_casegen["Male"]

il_casegen = il_casegen.rename(columns={"Female" : "cases_female", "Male" : "cases_male"})

# %%
# il_casegen

# %%
# merge of cases and vax
il_case_vax = pd.merge(il_casegen, il_vax, on=["date"], how="inner")

# %%
# need to shift the vax numbers as we did before
shiftcol = ["admin_janssen_diff", "admin_moderna_diff", "admin_pfizer_diff", "admin_unk_diff"]
il_case_vax[shiftcol] = il_case_vax[shiftcol].shift(1)

# %%
# il_case_vax

# %%
# applying % vaccinated per gender group

# male = 8,979,541 / 4,233,233 = 0.47143089
# female = 8,979,541 / 4,746,308 = 0.52856911

il_case_vax["admin_janssen_male"] = (il_case_vax["admin_janssen_diff"] * 0.47143089).round()

il_case_vax["admin_moderna_male"] = (il_case_vax["admin_moderna_diff"] * 0.47143089).round()

il_case_vax["admin_pfizer_male"] = (il_case_vax["admin_pfizer_diff"] * 0.47143089).round()

# female cols
il_case_vax["admin_janssen_female"] = (il_case_vax["admin_janssen_diff"] * 0.52856911).round()

il_case_vax["admin_moderna_female"] = (il_case_vax["admin_moderna_diff"] * 0.52856911).round()

il_case_vax["admin_pfizer_female"] = (il_case_vax["admin_pfizer_diff"] * 0.52856911).round()

# %%
il_case_vax
# Out:
#          date  cases_female  cases_male  case_tot  state  admin_janssen_diff  \
# 0  2021-01-01       63832.0     60405.0  124237.0      4                 NaN
# 1  2021-02-01       23768.0     24440.0   48208.0      4                 0.0
# 2  2021-03-01       34430.0     33716.0   68146.0      4                 0.0
# 3  2021-04-01       41537.0     37706.0   79243.0      4                 0.0
# 4  2021-05-01       16094.0     14105.0   30199.0      4            128349.0
# 5  2021-06-01        4271.0      3574.0    7845.0      4            183659.0
# 6  2021-07-01       25064.0     22142.0   47206.0      4             82759.0
# 7  2021-08-01       57919.0     53124.0  111043.0      4             61836.0
# 8  2021-09-01       46118.0     41180.0   87298.0      4             32683.0
# 9  2021-10-01       37788.0     34344.0   72132.0      4             41461.0
# 10 2021-11-01       81704.0     76323.0  158027.0      4             20101.0
# 11 2021-12-01      205781.0    172584.0  378365.0      4             15536.0
#
#     admin_moderna_diff  admin_pfizer_diff  admin_unk_diff  admin_janssen_male  \
# 0                  NaN                NaN             NaN                 NaN
# 1                  0.0                0.0             0.0                 0.0
# 2             415968.0           474188.0           185.0                 0.0
# 3             958915.0           892001.0           825.0                 0.0
# 4            1410282.0          1626525.0          1708.0             60508.0
# 5            1257608.0          2034106.0          2477.0             86583.0
# 6             704081.0          1360702.0          2658.0             39015.0
# 7             341640.0           894424.0          2663.0             29151.0
# 8             145697.0           498166.0          4297.0             15408.0
# 9             169286.0           771568.0          2584.0             19546.0
# 10            138630.0           519956.0          2203.0              9476.0
# 11            241753.0           665108.0          -311.0              7324.0
#
#     admin_moderna_male  admin_pfizer_male  admin_janssen_female  \
# 0                  NaN                NaN                   NaN
# 1                  0.0                0.0                   0.0
# 2             196100.0           223547.0                   0.0
# 3             452062.0           420517.0                   0.0
# 4             664850.0           766794.0               67841.0
# 5             592875.0           958940.0               97076.0
# 6             331926.0           641477.0               43744.0
# 7             161060.0           421659.0               32685.0
# 8              68686.0           234851.0               17275.0
# 9              79807.0           363741.0               21915.0
# 10             65354.0           245123.0               10625.0
# 11            113970.0           313552.0                8212.0
#
#     admin_moderna_female  admin_pfizer_female
# 0                    NaN                  NaN
# 1                    0.0                  0.0
# 2               219868.0             250641.0
# 3               506853.0             471484.0
# 4               745432.0             859731.0
# 5               664733.0            1075166.0
# 6               372155.0             719225.0
# 7               180580.0             472765.0
# 8                77011.0             263315.0
# 9                89479.0             407827.0
# 10               73276.0             274833.0
# 11              127783.0             351556.0

# %%
# LINEAR REGRESSIONS FOR CASES GENDER

ilf_formula = "cases_female ~ admin_janssen_female + admin_moderna_female + admin_pfizer_female"
ilf_model = sm.ols(formula=ilf_formula, data =il_case_vax)
ilf_fitted = ilf_model.fit()

print(ilf_fitted.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           cases_female   R-squared:                       0.336
# Model:                            OLS   Adj. R-squared:                  0.051
# Method:                 Least Squares   F-statistic:                     1.179
# Date:                Wed, 16 Mar 2022   Prob (F-statistic):              0.384
# Time:                        19:23:06   Log-Likelihood:                -132.91
# No. Observations:                  11   AIC:                             273.8
# Df Residuals:                       7   BIC:                             275.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept             3.339e+04   4.29e+04      0.779      0.461   -6.79e+04    1.35e+05
# admin_janssen_female    -1.9988      1.507     -1.326      0.226      -5.562       1.564
# admin_moderna_female    -0.1920      0.150     -1.283      0.240      -0.546       0.162
# admin_pfizer_female      0.2706      0.217      1.248      0.252      -0.242       0.783
# ==============================================================================
# Omnibus:                       14.606   Durbin-Watson:                   1.163
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                8.332
# Skew:                           1.710   Prob(JB):                       0.0155
# Kurtosis:                       5.547   Cond. No.                     1.74e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.74e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Users/austinwahl/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=11
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %%
ilm_formula = "cases_male ~ admin_janssen_male + admin_moderna_male + admin_pfizer_male"
ilm_model = sm.ols(formula=ilm_formula, data = il_case_vax)
ilm_fitted = ilm_model.fit()

print(ilm_fitted.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             cases_male   R-squared:                       0.358
# Model:                            OLS   Adj. R-squared:                  0.083
# Method:                 Least Squares   F-statistic:                     1.301
# Date:                Wed, 16 Mar 2022   Prob (F-statistic):              0.347
# Time:                        19:23:06   Log-Likelihood:                -130.76
# No. Observations:                  11   AIC:                             269.5
# Df Residuals:                       7   BIC:                             271.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept           3.344e+04   3.52e+04      0.949      0.374   -4.99e+04    1.17e+05
# admin_janssen_male    -1.8666      1.390     -1.343      0.221      -5.152       1.419
# admin_moderna_male    -0.1802      0.138     -1.306      0.233      -0.506       0.146
# admin_pfizer_male      0.2473      0.200      1.237      0.256      -0.226       0.720
# ==============================================================================
# Omnibus:                       13.197   Durbin-Watson:                   1.149
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                7.120
# Skew:                           1.610   Prob(JB):                       0.0284
# Kurtosis:                       5.273   Cond. No.                     1.56e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.56e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Users/austinwahl/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=11
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %%
# merging 4 states back together

# %%
ca_covidgen = ca_covidgen.set_index("date")
fl_case_vax = fl_case_vax.set_index("date")
ny_case_vax = ny_case_vax.set_index("date")
il_case_vax = il_case_vax.set_index("date")

# %%
ca_covidgen
# Out:
#             cases_female  cases_male  case_tot  state  admin_janssen_diff  \
# date
# 2021-01-01        444099      416152    860251      1                 NaN
# 2021-02-01         90725       88556    179281      1                 0.0
# 2021-03-01         40960       40596     81556      1                 0.0
# 2021-04-01         32799       31611     64410      1               352.0
# 2021-05-01         19084       17779     36863      1            370149.0
# 2021-06-01         17639       16652     34291      1            731072.0
# 2021-07-01        102884       96959    199843      1            255978.0
# 2021-08-01        207631      197718    405349      1            198595.0
# 2021-09-01        125332      120407    245739      1            115222.0
# 2021-10-01         89587       84546    174133      1            106021.0
# 2021-11-01         82027       77829    159856      1             81557.0
# 2021-12-01        167106      151341    318447      1             85671.0
#
#             admin_moderna_diff  admin_pfizer_diff  admin_unk_diff  \
# date
# 2021-01-01                 NaN                NaN             NaN
# 2021-02-01                 0.0                0.0             0.0
# 2021-03-01           1539751.0          1539036.0             0.0
# 2021-04-01           2859867.0          2792564.0            10.0
# 2021-05-01           4269462.0          4856850.0          1626.0
# 2021-06-01           4850227.0          6633513.0          1859.0
# 2021-07-01           2625843.0          4768392.0          1681.0
# 2021-08-01           1147495.0          2951158.0          1708.0
# 2021-09-01            680467.0          1705282.0          1791.0
# 2021-10-01            702586.0          2022994.0          3802.0
# 2021-11-01            668299.0          1858195.0           768.0
# 2021-12-01            939535.0          2693022.0          1348.0
#
#             pfizer_malepct  moderna_malepct  jj_malepct  pfizer_femalepct  \
# date
# 2021-01-01        0.430412         0.435735    0.560284          0.569588
# 2021-02-01        0.401580         0.436636    0.539130          0.598420
# 2021-03-01        0.435514         0.438605    0.484914          0.564486
# 2021-04-01        0.479150         0.473237    0.516532          0.520850
# 2021-05-01        0.501734         0.508539    0.622582          0.498266
# 2021-06-01        0.493341         0.517333    0.655199          0.506659
# 2021-07-01        0.478236         0.508738    0.631365          0.521764
# 2021-08-01        0.509855         0.550691    0.616745          0.490145
# 2021-09-01        0.479664         0.507829    0.612239          0.520336
# 2021-10-01        0.433021         0.480289    0.596899          0.566979
# 2021-11-01        0.462795         0.462143    0.555050          0.537205
# 2021-12-01        0.471866         0.479848    0.569164          0.528134
#
#             moderna_femalepct  jj_femalepct  admin_janssen_male  \
# date
# 2021-01-01           0.564265      0.439716                 NaN
# 2021-02-01           0.563364      0.460870                 0.0
# 2021-03-01           0.561395      0.515086                 0.0
# 2021-04-01           0.526763      0.483468               182.0
# 2021-05-01           0.491461      0.377418            230448.0
# 2021-06-01           0.482667      0.344801            478998.0
# 2021-07-01           0.491262      0.368635            161616.0
# 2021-08-01           0.449309      0.383255            122483.0
# 2021-09-01           0.492171      0.387761             70543.0
# 2021-10-01           0.519711      0.403101             63284.0
# 2021-11-01           0.537857      0.444950             45268.0
# 2021-12-01           0.520152      0.430836             48761.0
#
#             admin_moderna_male  admin_pfizer_male  admin_janssen_female  \
# date
# 2021-01-01                 NaN                NaN                   NaN
# 2021-02-01                 0.0                0.0                   0.0
# 2021-03-01            675342.0           670271.0                   0.0
# 2021-04-01           1353396.0          1338058.0                 170.0
# 2021-05-01           2171187.0          2436846.0              139701.0
# 2021-06-01           2509180.0          3272583.0              252074.0
# 2021-07-01           1335867.0          2280415.0               94362.0
# 2021-08-01            631915.0          1504662.0               76112.0
# 2021-09-01            345561.0           817963.0               44679.0
# 2021-10-01            337444.0           875999.0               42737.0
# 2021-11-01            308850.0           859963.0               36289.0
# 2021-12-01            450834.0          1270746.0               36910.0
#
#             admin_moderna_female  admin_pfizer_female
# date
# 2021-01-01                   NaN                  NaN
# 2021-02-01                   0.0                  0.0
# 2021-03-01              864409.0             868765.0
# 2021-04-01             1506471.0            1454506.0
# 2021-05-01             2098275.0            2420004.0
# 2021-06-01             2341047.0            3360930.0
# 2021-07-01             1289976.0            2487977.0
# 2021-08-01              515580.0            1446496.0
# 2021-09-01              334906.0             887319.0
# 2021-10-01              365142.0            1146995.0
# 2021-11-01              359449.0             998232.0
# 2021-12-01              488701.0            1422276.0
