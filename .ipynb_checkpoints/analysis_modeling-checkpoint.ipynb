# %% [markdown]
# # Which COVID-19 Vaccine is Best for You?
# ## DS4A Team 55 Preliminary EDA

# %%
import pandas as pd
import numpy as np
import math
import base64
import matplotlib.pyplot as plt
import seaborn as sns
from sodapy import Socrata
import zipfile

# %%
# increase the size and quality of any plots we produce
import matplotlib as mpl
mpl.rcParams["figure.dpi"] = 300

# %% [markdown]
# ## state_vax.csv
# Vaccine administration data for states within the U.S., including the District of Columbia from 12/13/2020 to the present, updated daily.

# %%
client = Socrata(
        domain = "data.cdc.gov",
        app_token = "bsYMLkKAQhIIVd7wzBzp5BiCR",
        timeout=10
        )
results = client.get_all("unsk-b7fc")

# convert to pandas DataFrame
df = pd.DataFrame.from_records(results)
df.sample(10)
# Out:
#                           date mmwr_week location distributed  \
# 23159  2021-02-10T00:00:00.000         6       AR      581875
# 1755   2022-01-06T00:00:00.000         1       MS     4798705
# 22205  2021-02-24T00:00:00.000         8       MO     1519205
# 22379  2021-02-22T00:00:00.000         8      BP2       49175
# 11950  2021-08-01T00:00:00.000        31       WY      529845
# 13509  2021-07-08T00:00:00.000        27       GA    11258655
# 22495  2021-02-20T00:00:00.000         7       TN     1477175
# 1999   2022-01-02T00:00:00.000         0       MD    13280810
# 19117  2021-04-13T00:00:00.000        15       WV     1441365
# 2880   2021-12-19T00:00:00.000        51       NJ    18174935
#
#       distributed_janssen distributed_moderna distributed_pfizer  \
# 23159                   0                   0                  0
# 1755               216300             1929740            2652665
# 22205                   0                   0                  0
# 22379                   0                   0                  0
# 11950               34000              255740             240105
# 13509              599200             4772600            5886855
# 22495                   0                   0                  0
# 1999               590900             4513320            8176590
# 19117               95500              665900             679965
# 2880               888800             6524540           10761595
#
#       distributed_unk_manuf dist_per_100k distributed_per_100k_12plus  ...  \
# 23159                     0         19281                           0  ...
# 1755                      0        161239                      190317  ...
# 22205                     0         24753                           0  ...
# 22379                     0             0                           0  ...
# 11950                     0         91548                      107973  ...
# 13509                     0        106039                      125262  ...
# 22495                     0         21630                           0  ...
# 1999                      0        219674                      257236  ...
# 19117                     0         80427                           0  ...
# 2880                      0        204622                      238567  ...
#
#       administered_dose1_recip_5pluspop_pct series_complete_5plus  \
# 23159                                     0                     0
# 1755                                   59.9               1450271
# 22205                                     0                     0
# 22379                                     0                     0
# 11950                                     0                     0
# 13509                                     0                     0
# 22495                                     0                     0
# 1999                                   85.7               4260287
# 19117                                     0                     0
# 2880                                   87.3               6204429
#
#       series_complete_5pluspop_pct administered_5plus admin_per_100k_5plus  \
# 23159                            0                  0                    0
# 1755                          51.9            3515000               125865
# 22205                            0                  0                    0
# 22379                            0                  0                    0
# 11950                            0                  0                    0
# 13509                            0                  0                    0
# 22495                            0                  0                    0
# 1999                            75           10467738               184170
# 19117                            0                  0                    0
# 2880                          74.1           14522212               173555
#
#       distributed_per_100k_5plus series_complete_moderna_5plus  \
# 23159                          0                           NaN
# 1755                      171832                        564612
# 22205                          0                           NaN
# 22379                          0                           NaN
# 11950                          0                           NaN
# 13509                          0                           NaN
# 22495                          0                           NaN
# 1999                      233663                       1456802
# 19117                          0                           NaN
# 2880                      217209                       2208586
#
#       series_complete_pfizer_5plus series_complete_janssen_5plus  \
# 23159                          NaN                           NaN
# 1755                        803979                         80916
# 22205                          NaN                           NaN
# 22379                          NaN                           NaN
# 11950                          NaN                           NaN
# 13509                          NaN                           NaN
# 22495                          NaN                           NaN
# 1999                       2485290                        314438
# 19117                          NaN                           NaN
# 2880                       3507197                        488281
#
#       series_complete_unk_manuf_5plus
# 23159                             NaN
# 1755                              764
# 22205                             NaN
# 22379                             NaN
# 11950                             NaN
# 13509                             NaN
# 22495                             NaN
# 1999                             3757
# 19117                             NaN
# 2880                              365
#
# [10 rows x 80 columns]

# %%
df.columns
# Out:
# Index(['date', 'state', 'admin_12plus', 'admin_18plus', 'admin_65plus',
#        'admin_janssen', 'admin_moderna', 'admin_pfizer', 'admin_unk',
#        'admin_per_100k', 'admin_per_100k_12plus', 'admin_per_100k_18plus',
#        'admin_per_100k_65plus', 'admin_dose1', 'admin_dose1_pop_pct',
#        'admin_dose1_12plus', 'admin_dose1_12plus_pop_pct',
#        'admin_dose1_18plus', 'admin_dose1_18plus_pop_pct',
#        'admin_dose1_65plus', 'admin_dose1_65plus_pop_pct', 'series_complete',
#        'series_complete_pop_pct', 'series_complete_12plus',
#        'series_complete_12plus_pop_pct', 'series_complete_18plus',
#        'series_complete_18plus_pop_pct', 'series_complete_65plus',
#        'series_complete_65plus_pop_pct', 'series_complete_janssen',
#        'series_complete_moderna', 'series_complete_pfizer',
#        'series_complete_unk', 'series_complete_janssen_12plus',
#        'series_complete_moderna_12plus', 'series_complete_pfizer_12plus',
#        'series_complete_unk_12plus', 'series_complete_janssen_18plus',
#        'series_complete_moderna_18plus', 'series_complete_pfizer_18plus',
#        'series_complete_unk_18plus', 'series_complete_janssen_65plus',
#        'series_complete_moderna_65plus', 'series_complete_pfizer_65plus',
#        'series_complete_unk_65plus', 'additional_doses',
#        'additional_doses_vax_pct', 'additional_doses_18plus',
#        'additional_doses_18plus_vax_pct', 'additional_doses_65plus',
#        'additional_doses_65plus_vax_pct', 'additional_doses_moderna',
#        'additional_doses_pfizer', 'additional_doses_janssen',
#        'additional_doses_unk_manuf'],
#       dtype='object')

# %%
df.sort_values(by="date", ascending=True)
# Out:
#                           date mmwr_week location distributed  \
# 26903  2020-12-13T00:00:00.000        51       AS        3900
# 26898  2020-12-13T00:00:00.000        51       VI         975
# 26899  2020-12-13T00:00:00.000        51       US       13650
# 26902  2020-12-13T00:00:00.000        51       MP        4875
# 26901  2020-12-13T00:00:00.000        51      LTC           0
# ...                        ...       ...      ...         ...
# 36     2022-02-02T00:00:00.000         5       NC    20227300
# 35     2022-02-02T00:00:00.000         5       SC     9648555
# 34     2022-02-02T00:00:00.000         5       KS     5568535
# 32     2022-02-02T00:00:00.000         5       MD    14539490
# 0      2022-02-02T00:00:00.000         5       PR     7122970
#
#       distributed_janssen distributed_moderna distributed_pfizer  \
# 26903                   0                   0                  0
# 26898                   0                   0                  0
# 26899                   0                   0                  0
# 26902                   0                   0                  0
# 26901                   0                   0                  0
# ...                   ...                 ...                ...
# 36                 911900             7496560           11818840
# 35                 448500             3899520            5300535
# 34                 253300             2110360            3204875
# 32                 598700             4913220            9027570
# 0                  213300             2503640            4406030
#
#       distributed_unk_manuf dist_per_100k distributed_per_100k_12plus  ...  \
# 26903                     0          7003                           0  ...
# 26898                     0           931                           0  ...
# 26899                     0             4                           0  ...
# 26902                     0          8570                           0  ...
# 26901                     0             0                           0  ...
# ...                     ...           ...                         ...  ...
# 36                        0        192860                      225110  ...
# 35                        0        187397                      218294  ...
# 34                        0        191141                      227130  ...
# 32                        0        240494                      281615  ...
# 0                         0        223032                      250079  ...
#
#       administered_dose1_recip_5pluspop_pct series_complete_5plus  \
# 26903                                     0                     0
# 26898                                     0                     0
# 26899                                     0                     0
# 26902                                     0                     0
# 26901                                     0                     0
# ...                                     ...                   ...
# 36                                       86               6135324
# 35                                     69.7               2830831
# 34                                     77.5               1723439
# 32                                     89.1               4397043
# 0                                        95               2541672
#
#       series_complete_5pluspop_pct administered_5plus admin_per_100k_5plus  \
# 26903                            0                  0                    0
# 26898                            0                  0                    0
# 26899                            0                  0                    0
# 26902                            0                  0                    0
# 26901                            0                  0                    0
# ...                            ...                ...                  ...
# 36                            62.1           15758934               159531
# 35                            58.3            7091772               146034
# 34                            63.2            4328895               158685
# 32                            77.4           11205577               197151
# 0                             82.6            6545054               212763
#
#       distributed_per_100k_5plus series_complete_moderna_5plus  \
# 26903                          0                           NaN
# 26898                          0                           NaN
# 26899                          0                           NaN
# 26902                          0                           NaN
# 26901                          0                           NaN
# ...                          ...                           ...
# 36                        204765                       2137332
# 35                        198683                       1023888
# 34                        204126                        618383
# 32                        255808                       1480455
# 0                         231550                        939576
#
#       series_complete_pfizer_5plus series_complete_janssen_5plus  \
# 26903                          NaN                           NaN
# 26898                          NaN                           NaN
# 26899                          NaN                           NaN
# 26902                          NaN                           NaN
# 26901                          NaN                           NaN
# ...                            ...                           ...
# 36                         3523146                        474704
# 35                         1603177                        203403
# 34                          981098                        123287
# 32                         2591733                        320843
# 0                          1463313                        138654
#
#       series_complete_unk_manuf_5plus
# 26903                             NaN
# 26898                             NaN
# 26899                             NaN
# 26902                             NaN
# 26901                             NaN
# ...                               ...
# 36                                142
# 35                                363
# 34                                671
# 32                               4012
# 0                                 129
#
# [26904 rows x 80 columns]

# %%
# df.shape

# %%
# remove all distribution cols
# remove "Administered", this is the total for 1st dose and complete series
# remove all 5plus cols, very recently approved and sporadic across states
# remove additional doses for 50plus, age group doesn't show up elsewhere in dataset


df = df.drop(columns= ["mmwr_week","distributed", "distributed_janssen", "distributed_moderna", 
                       "distributed_pfizer", "distributed_unk_manuf", "dist_per_100k","distributed_per_100k_12plus",
                       "distributed_per_100k_18plus", "distributed_per_100k_65plus", "distributed_per_100k_5plus",
                       "administered","administered_dose1_recip_5plus", "recip_administered",
                       "administered_dose1_recip_5pluspop_pct", "series_complete_5plus", "series_complete_5pluspop_pct", 
                       "administered_5plus", "admin_per_100k_5plus", "series_complete_moderna_5plus",
                       "series_complete_pfizer_5plus", "series_complete_janssen_5plus", "series_complete_unk_manuf_5plus",
                       "additional_doses_50plus", "additional_doses_50plus_vax_pct"], axis=1)

# %%
# abbreviating column names for readability
# cols in api data are labelled differently than csv directly from data.cdc.gov, values match up so renaming those cols

rename_cols = {"administered_12plus":"admin_12plus",
               "location":"state",
               "administered_18plus":"admin_18plus",
               "administered_65plus":"admin_65plus",
               "administered_janssen":"admin_janssen",
               "administered_moderna":"admin_moderna",
               "administered_pfizer":"admin_pfizer",
               "administered_unk_manuf":"admin_unk",
               "administered_dose1_recip":"admin_dose1",
               "administered_dose1_pop_pct":"admin_dose1_pop_pct",
               "administered_dose1_recip_1":"admin_dose1_12plus",
               "administered_dose1_recip_2":"admin_dose1_12plus_pop_pct",
               "administered_dose1_recip_3":"admin_dose1_18plus",
               "administered_dose1_recip_4":"admin_dose1_18plus_pop_pct",
               "administered_dose1_recip_5":"admin_dose1_65plus",
               "administered_dose1_recip_6":"admin_dose1_65plus_pop_pct",
               "series_complete_yes":"series_complete",
               "series_complete_12pluspop":"series_complete_12plus_pop_pct",
               "series_complete_18pluspop":"series_complete_18plus_pop_pct",
               "series_complete_65pluspop":"series_complete_65plus_pop_pct",
               "series_complete_unk_manuf":"series_complete_unk",
               "series_complete_unk_manuf_1":"series_complete_unk_12plus",
               "series_complete_unk_manuf_2":"series_complete_unk_18plus",
               "series_complete_unk_manuf_3":"series_complete_unk_65plus",
               "series_complete_12pluspop_pct":"series_complete_12plus_pop_pct",
               "series_complete_18pluspop_pct":"series_complete_18plus_pop_pct",
               "series_complete_65pluspop_pct":"series_complete_65plus_pop_pct"
               }
df = df.rename(columns=rename_cols)

# %%
# df.columns

# %%
# see data types of df
# all types = object, need to change to ints and floats
# df.dtypes

# %%
# show cols with NaNs
# cols with NaNs are additional dose cols, after investigating this happens when other additional dose cols are 0
df.columns[df.isnull().any()]
# Out:
# Index(['additional_doses', 'additional_doses_vax_pct',
#        'additional_doses_18plus', 'additional_doses_18plus_vax_pct',
#        'additional_doses_65plus', 'additional_doses_65plus_vax_pct',
#        'additional_doses_moderna', 'additional_doses_pfizer',
#        'additional_doses_janssen', 'additional_doses_unk_manuf'],
#       dtype='object')

# %%
# replace NaNs with 0 to fill in values
nan_col = ['additional_doses', 'additional_doses_vax_pct',
           'additional_doses_18plus', 'additional_doses_18plus_vax_pct',
           'additional_doses_65plus', 'additional_doses_65plus_vax_pct',
           'additional_doses_moderna', 'additional_doses_pfizer',
           'additional_doses_janssen', 'additional_doses_unk_manuf']
df[nan_col] = df[nan_col].fillna(0)

# %%
to_int = ['admin_12plus', 'admin_18plus', 'admin_65plus','admin_janssen',
          'admin_moderna', 'admin_pfizer', 'admin_unk','admin_per_100k',
          'admin_per_100k_12plus', 'admin_per_100k_18plus','admin_per_100k_65plus',
          'admin_dose1', 'admin_dose1_12plus', 'admin_dose1_18plus',
          'admin_dose1_65plus', 'series_complete_12plus', 'series_complete_18plus',
          'series_complete','series_complete_65plus', 'series_complete_janssen', 'series_complete_moderna',
          'series_complete_pfizer','series_complete_unk', 'series_complete_janssen_12plus',
          'series_complete_moderna_12plus', 'series_complete_pfizer_12plus', 'series_complete_unk_12plus',
          'series_complete_janssen_18plus', 'series_complete_moderna_18plus', 'series_complete_pfizer_18plus',
          'series_complete_unk_18plus', 'series_complete_janssen_65plus', 'series_complete_moderna_65plus',
          'series_complete_pfizer_65plus', 'series_complete_unk_65plus', 'additional_doses',
          'additional_doses_18plus', 'additional_doses_65plus', 'additional_doses_moderna',
          'additional_doses_pfizer', 'additional_doses_janssen', 'additional_doses_unk_manuf'
         ]

to_float = ['admin_dose1_pop_pct', 'admin_dose1_12plus_pop_pct', 'admin_dose1_18plus_pop_pct',
            'admin_dose1_65plus_pop_pct', 'series_complete_pop_pct', 'series_complete_12plus_pop_pct',
            'series_complete_12plus_pop_pct', 'series_complete_18plus_pop_pct', 'series_complete_65plus_pop_pct',
            'additional_doses_vax_pct', 'additional_doses_18plus_vax_pct', 'additional_doses_65plus_vax_pct'
           ]

df[to_int] = df[to_int].astype("int")
df[to_float] = df[to_float].astype("float")

# %%
# checking that data types hace been converted correctly
# df.dtypes

# %%
# removing locations outside of the contential united states as well as united states total

drop_location = ["AS", "BP2", "DD2", "FM", "GU",
                 "IH2", "MH", "MP", "PR", "RP",
                 "US", "VA2", "VI", "LTC"]
df = df[~df["state"].isin(drop_location)]

# checking that location vals = 51, including DC

df.state.nunique()
# Out:
# 51

# %%
# converting "date" col to datetime
df["date"] = pd.to_datetime(df["date"])

# %%
# filter location to New York
df_ny = df.loc[df["state"] == "NY"]

# %%
# creating a new df with all values on a daily basis instead of a running total
df_ny_daily = df_ny.drop(columns="state").set_index("date")
df_ny_daily = df_ny_daily.diff(periods=-1)
df_ny_daily.head(50)
# Out:
#             admin_12plus  admin_18plus  admin_65plus  admin_janssen  \
# date
# 2022-02-02       49261.0       43520.0        5749.0         1120.0
# 2022-02-01       32802.0       29186.0        3318.0          783.0
# 2022-01-31       17424.0       14387.0        1130.0          377.0
# 2022-01-30       49846.0       42207.0        4525.0          888.0
# 2022-01-29       61485.0       55269.0        7659.0         1403.0
# 2022-01-28       58849.0       53267.0        7770.0         1242.0
# 2022-01-27       56316.0       50669.0        7246.0         1249.0
# 2022-01-26       66938.0       59658.0        8305.0         1499.0
# 2022-01-25       42522.0       38668.0        5631.0         1076.0
# 2022-01-24       40555.0       33767.0        3418.0          504.0
# 2022-01-23       59130.0       49305.0        5272.0         1078.0
# 2022-01-22       69000.0       61743.0        8104.0         1563.0
# 2022-01-21       69283.0       62101.0        8413.0         1741.0
# 2022-01-20       76876.0       69401.0        9547.0         1509.0
# 2022-01-19       66186.0       59251.0        7376.0         1548.0
# 2022-01-18       39571.0       34044.0        4165.0         1066.0
# 2022-01-17       40760.0       33661.0        3391.0          905.0
# 2022-01-16       89756.0       75232.0        8536.0         1598.0
# 2022-01-15       94353.0       84591.0       12640.0         2618.0
# 2022-01-14       90081.0       81501.0       13035.0         2441.0
# 2022-01-13       90693.0       82079.0       12180.0         2219.0
# 2022-01-12       85721.0       77215.0       11199.0         2022.0
# 2022-01-11       56393.0       51470.0        7551.0         1290.0
# 2022-01-10       48280.0       40214.0        5004.0         1063.0
# 2022-01-09       90057.0       77234.0        9196.0         1589.0
# 2022-01-08       92389.0       84396.0       12657.0         1920.0
# 2022-01-18                     399.0                         0.0
# 2022-01-17                     342.0                         0.0
# 2022-01-16                     802.0                         2.0
# 2022-01-15                    1027.0                         3.0
# 2022-01-14                    1221.0                         4.0
# 2022-01-13                     869.0                         5.0
# 2022-01-12                     871.0                         2.0
# 2022-01-11                     532.0                         1.0
# 2022-01-10                     455.0                         1.0
# 2022-01-09                     742.0                         3.0
# 2022-01-08                     914.0                        11.0
# 2022-01-07                     981.0                         6.0
# 2022-01-06                     898.0                         3.0
# 2022-01-05                     893.0                         4.0
# 2022-01-04                     467.0                         3.0
# 2022-01-03                     333.0                         0.0
# 2022-01-02                       0.0                         0.0
# 2022-01-01                     824.0                         0.0
# 2021-12-31                     914.0                         6.0
# 2021-12-30                     790.0                         3.0
# 2021-12-29                     820.0                         6.0
# 2021-12-28                     485.0                         5.0
# 2021-12-27                     181.0                         1.0
# 2021-12-26                     173.0                         0.0
# 2021-12-25                     857.0                         0.0
# 2021-12-24                     966.0                         7.0
# 2021-12-23                    1117.0                         2.0
# 2021-12-22                    1030.0                         0.0
# 2021-12-21                     666.0                         4.0
# 2021-12-20                     543.0                         0.0
# 2021-12-19                     969.0                         5.0
# 2021-12-18                    1561.0                         8.0
# 2021-12-17                    2006.0                         3.0
# 2021-12-16                    1801.0                         2.0
# 2021-12-15                    1915.0                         1.0
#
# [50 rows x 53 columns]

# %%
# this value appears as an outlier but was manually calculated from raw dataset and is correct
print(df_ny_daily["admin_pfizer"].max())
# Out:
# 581745.0

# %%
# set index to date to extract rows for the first of each month, aligns with how other datasets are reported
df_ny_m = df_ny.set_index("date")
df_ny_m = df_ny_m.groupby(df_ny_m.index.strftime("%Y-%m")).tail(1)
df_ny_m = df_ny_m.reset_index().sort_values(by="date", ascending=True)
# df_ny_m.head(10)

# %%
# first reported date and most recent date for vax data, updated daily
print(df_ny["date"].min())
print(df_ny["date"].max())
# Out:
# 2020-12-14 00:00:00
# 2022-02-02 00:00:00

# %% [markdown]
# # covid_cases
# Covid cases in NY

# %%
# #read data
# covid_df = pd.read_csv("data/covid_cases_4states.csv.zip", compression="zip")
# covid_df.head()

with zipfile.ZipFile("data/covid_cases_4states.csv.zip") as z:
    with z.open("covid_cases_4states.csv") as f:
        covid_df = pd.read_csv(f, low_memory=False)

covid_df.head()
# # open zipped dataset
# with zipfile.ZipFile("test.zip") as z:
#    # open the csv file in the dataset
#    with z.open("test.csv") as f:
       
#       # read the dataset
#       train = pd.read_csv(f)
# Out:
#   case_month res_state  state_fips_code res_county  county_fips_code  \
# 0    2021-10        NY               36    CLINTON           36019.0
# 1    2021-07        FL               12      BAKER           12003.0
# 2    2020-09        NY               36    STEUBEN           36101.0
# 3    2021-02        FL               12    MANATEE           12081.0
# 4    2021-03        FL               12     MARION           12083.0
#
#         age_group     sex     race        ethnicity  \
# 0       65+ years  Female  Missing              NaN
# 1  50 to 64 years  Female      NaN              NaN
# 2  50 to 64 years  Female  Missing              NaN
# 3  18 to 49 years  Female  Unknown  Hispanic/Latino
# 4  50 to 64 years  Female  Unknown  Hispanic/Latino
#
#    case_positive_specimen_interval  case_onset_interval  process exposure_yn  \
# 0                              NaN                  NaN  Missing     Missing
# 1                              NaN                  0.0  Missing     Missing
# 2                              0.0                  NaN  Missing     Missing
# 3                              NaN                  NaN  Missing     Missing
# 4                              NaN                  NaN  Missing     Missing
#
#               current_status symptom_status  hosp_yn   icu_yn death_yn  \
# 0  Laboratory-confirmed case        Missing  Missing  Missing       No
# 1  Laboratory-confirmed case    Symptomatic       No  Missing       No
# 2  Laboratory-confirmed case        Missing  Missing  Missing       No
# 3  Laboratory-confirmed case        Missing  Missing  Missing  Missing
# 4  Laboratory-confirmed case        Missing  Missing  Missing  Missing
#
#   underlying_conditions_yn
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
covid_df.columns #column names
# Out:
# Index(['case_month', 'res_state', 'state_fips_code', 'res_county',
#        'county_fips_code', 'age_group', 'sex', 'race', 'ethnicity',
#        'case_positive_specimen_interval', 'case_onset_interval', 'process',
#        'exposure_yn', 'current_status', 'symptom_status', 'hosp_yn', 'icu_yn',
#        'death_yn', 'underlying_conditions_yn'],
#       dtype='object')

# %%
# covid_df.dtypes

# %%
covid_df.shape
# Out:
# (11685325, 19)

# %%
#data cleaning
covid_df['case_month'] = pd.to_datetime(covid_df['case_month']) #convert to date

# %%
# dropping irrelevant columns
covid_df = covid_df.drop(columns=["case_positive_specimen_interval", "case_onset_interval", "process", "exposure_yn", "current_status"])

# %%
# rename cols for readability and uniformify across datasets
covid_rename = {"case_month":"date", "res_state":"state",
               "res_county":"county"}

covid_df = covid_df.rename(columns=covid_rename)

# %%
# converting data types 
to_str = ["state", "county", "age_group", "sex", "race", "ethnicity",
          "symptom_status", "hosp_yn", "icu_yn", "death_yn", "underlying_conditions_yn"]
covid_df[to_str] = covid_df[to_str].astype(str)

# %%
# show cols with NaNs
covid_df.columns[covid_df.isnull().any()]
# Out:
# Index(['county_fips_code'], dtype='object')

# %%
# fill NaNs in county_fips_code with "Not Available"
covid_df["county_fips_code"] = covid_df["county_fips_code"].fillna("Not Available")

# shows all values within the race col
covid_df.race.unique()

# rename nan, Missing, and Unknown to Not Available
rename_covid_nan = {"nan":"Not Available",
                     "Missing":"Not Available",
                     "Unknown":"Not Available"}
covid_df["race"] = covid_df["race"].replace(rename_covid_nan).astype(str)

# same treatment for ethnicity as the race col
covid_df.ethnicity.unique()

covid_df["ethnicity"] = covid_df["ethnicity"].replace(rename_covid_nan).astype(str)

covid_df["county"] = covid_df["county"].replace({"nan":"Not Available"})

# checking for NaN string values and replace with "Not Available" in remaining cols
covid_df.age_group.unique()
covid_df["age_group"] = covid_df["age_group"].replace({"nan":"Not Available", "Missing":"Not Available"}).astype(str)

covid_df["sex"] = covid_df["sex"].replace(rename_covid_nan).astype(str)

covid_df["death_yn"] = covid_df["death_yn"].replace(rename_covid_nan).astype(str)

covid_df["underlying_conditions_yn"] = covid_df["underlying_conditions_yn"].replace(rename_covid_nan).astype(str)

rename_missing_unk = {"Missing":"Not Available",
                      "Unknown":"Not Available"}
rename_col = ["symptom_status", "hosp_yn", "icu_yn"]
covid_df[rename_col] = covid_df[rename_col].replace(rename_missing_unk).astype(str)

# %%
covid_df.sample(10, random_state = 42)
# Out:
#                date state  state_fips_code         county county_fips_code  \
# 11639060 2021-12-01    TX               48  Not Available    Not Available
# 7365273  2021-01-01    CA                6           KERN           6029.0
# 2826409  2020-05-01    CA                6       MONTEREY           6053.0
# 3894756  2021-08-01    NY               36         ORANGE          36071.0
# 8602615  2021-08-01    NY               36        SUFFOLK          36103.0
# 10347080 2021-09-01    FL               12     MIAMI-DADE          12086.0
# 5423655  2021-09-01    NY               36         MONROE          36055.0
# 5897489  2020-12-01    CA                6        ALAMEDA           6001.0
# 9556751  2021-01-01    NY               36         QUEENS          36081.0
# 1140622  2021-09-01    NY               36     CHAUTAUQUA          36013.0
#
#                age_group     sex            race            ethnicity  \
# 11639060  18 to 49 years    Male   Not Available        Not Available
# 7365273   18 to 49 years  Female   Not Available        Not Available
# 2826409   18 to 49 years    Male           White      Hispanic/Latino
# 3894756   18 to 49 years  Female   Not Available      Hispanic/Latino
# 8602615        65+ years    Male   Not Available        Not Available
# 10347080       65+ years  Female           White      Hispanic/Latino
# 5423655     0 - 17 years  Female           Black  Non-Hispanic/Latino
# 5897489   18 to 49 years    Male  Multiple/Other        Not Available
# 9556751   18 to 49 years  Female           White        Not Available
# 1140622   18 to 49 years  Female   Not Available        Not Available
#
#          symptom_status        hosp_yn         icu_yn       death_yn  \
# 11639060  Not Available  Not Available  Not Available  Not Available
# 7365273   Not Available  Not Available  Not Available  Not Available
# 2826409     Symptomatic             No  Not Available  Not Available
# 3894756     Symptomatic             No  Not Available             No
# 8602615   Not Available  Not Available  Not Available             No
# 10347080  Not Available             No  Not Available             No
# 5423655   Not Available  Not Available  Not Available             No
# 5897489   Not Available  Not Available  Not Available  Not Available
# 9556751   Not Available  Not Available  Not Available  Not Available
# 1140622   Not Available  Not Available  Not Available             No
#
#          underlying_conditions_yn
# 11639060            Not Available
# 7365273             Not Available
# 2826409             Not Available
# 3894756             Not Available
# 8602615             Not Available
# 10347080            Not Available
# 5423655             Not Available
# 5897489             Not Available
# 9556751             Not Available
# 1140622             Not Available

# %%
# covid_df.describe(include = 'all',datetime_is_numeric=True) #describe and include string columns

# %%
#covid cases trend
# trend_df = covid_df.groupby(['date']).size().reset_index(name = 'case_count').set_index('date')
# trend_df['case_count_per_100k'] = trend_df['case_count']/100000
# plt.plot(trend_df.index,trend_df['case_count_per_100k'])
# plt.title('COVID-19 Cases Have Spiked Twice And Is Trending Upwards')
# plt.xlabel('Date')
# plt.ylabel('Case Count (Hundred Thousand)')
# plt.xticks(rotation=90)
# plt.show()

# %%
# trend_df.head()

# %%
# comparing cases with vaccine administration rates
# case_vax_ax = ny_m_plt.plot(x="date", y=["admin_per_100k_12plus", "admin_per_100k_18plus", "admin_per_100k_65plus"], kind="line")
# trend_df.plot(y="case_count", kind="line", ax=case_vax_ax, title="COVID-19 Cases and Vaccinations per Age Group");

# %% [markdown]
# When comparing the COVID case trends with the trends in vaccine administration across each age group, it can be seen that the number of cases starts to sharply decline as the population recieves the vaccine. The case_count trend line was already falling when the vaccines were made available. However, once more of the population started to get vaccinated the case numbers stayed low up until the omicron variant began spreading around November of 2021 up until now (mid-January 2022).

# %%
# case_comp_ax = daily_plt.plot(x="date", y='series_complete', kind="line")
# trend_df.plot(y="case_count", kind="line", ax=case_comp_ax, title="COVID-19 Cases and Complete Vaccine Series");

# %%
# covid_65plus = covid_df.loc[covid_df["age_group"] == "65+ years"]

# %%
# df_covid65 = covid_65plus.groupby(['date']).size().reset_index(name = 'case_count').set_index('date')

# df_covid65.plot(title="Trend in COVID-19 Cases for Age 65+");

# %%
# covid65_ax = ny_m_plt.plot(x="date", y="admin_per_100k_65plus", kind="line")
# df_covid65.plot(y="case_count", kind="line", ax=covid65_ax, title="COVID-19 Cases and Vaccinations for Age 65+");

# %% [markdown]
# # Analyzing the Impact of Different Factors on Case Trends
# ### Applying multiple regression to a new data frame containing case counts for each state by month, vaccine administration per month for each manufacturer, and analyzing demographic factors

# %%
# cases per state

cases_4state = covid_df.groupby(["date", "state"], as_index=False).size()
cases_4state = cases_4state.rename(columns={"size":"cases"})
cases_4state = cases_4state[~(cases_4state["date"] <= "2020-12-01")]

# %%
cases_4state
# Out:
#          date state   cases
# 48 2021-01-01    CA  877185
# 49 2021-01-01    FL  207612
# 50 2021-01-01    NY  333399
# 51 2021-01-01    TX    5057
# 52 2021-02-01    CA  182380
# 53 2021-02-01    FL  165000
# 54 2021-02-01    NY  199327
# 55 2021-02-01    TX    2108
# 56 2021-03-01    CA   83365
# 57 2021-03-01    FL  330204
# 58 2021-03-01    NY  222687
# 59 2021-03-01    TX    1242
# 60 2021-04-01    CA   65972
# 61 2021-04-01    FL  111786
# 62 2021-04-01    NY  144255
# 63 2021-04-01    TX    1086
# 64 2021-05-01    CA   38232
# 65 2021-05-01    FL   54597
# 66 2021-05-01    NY   42055
# 67 2021-05-01    TX     589
# 68 2021-06-01    CA   35709
# 69 2021-06-01    FL   49974
# 70 2021-06-01    NY   12562
# 71 2021-06-01    TX     616
# 72 2021-07-01    CA  203143
# 73 2021-07-01    FL  115593
# 74 2021-07-01    NY   47079
# 75 2021-07-01    TX    1097
# 76 2021-08-01    CA  414353
# 77 2021-08-01    FL  268491
# 78 2021-08-01    NY  125079
# 79 2021-08-01    TX    3297
# 80 2021-09-01    CA  251191
# 81 2021-09-01    FL  287957
# 82 2021-09-01    NY  138688
# 83 2021-09-01    TX    2489
# 84 2021-10-01    CA  178486
# 85 2021-10-01    FL  183619
# 86 2021-10-01    NY  117439
# 87 2021-10-01    TX    1018
# 88 2021-11-01    CA  163753
# 89 2021-11-01    FL   46151
# 90 2021-11-01    NY  175322
# 91 2021-11-01    TX   47193
# 92 2021-12-01    CA  326143
# 93 2021-12-01    FL   18569
# 94 2021-12-01    NY  544276
# 95 2021-12-01    TX   48463

# %%
keep_state = ["NY", "CA", "FL", "TX"]
df_4state = df.loc[df["state"].isin(keep_state)]


# df_4state_m = df_4state.set_index("date")
# df_4state_m = df_4state_m.groupby(df_4state_m.index.strftime("%Y-%m")).tail(1)
# df_4state_m = df_4state_m.reset_index().sort_values(by="date", ascending=True)
# manuf_4state_m = df_4state_m[["date","state", "admin_janssen", "admin_moderna", "admin_pfizer", "admin_unk"
# 41 2021-11-01    FL   46151        1250121       10609037      16698264
# 42 2021-11-01    NY  175322        1179846       10090429      16394605
# 43 2021-11-01    TX   47193        1287393       13012068      20354864
# 44 2021-12-01    CA  326143        2084243       22644200      35024428
# 45 2021-12-01    FL   18569        1329140       11639507      17935923
# 46 2021-12-01    NY  544276        1245561       11046085      17722694
# 47 2021-12-01    TX   48463        1374509       14081313      21900136
#
#     admin_unk
# 0           0
# 1          21
# 2          11
# 3           0
# 4           0
# 5        1322
# 6         211
# 7           0
# 8          10
# 9        5239
# 10        456
# 11        144
# 12       1636
# 13      13646
# 14       1268
# 15        599
# 16       3495
# 17      25210
# 18       2942
# 19        749
# 20       5176
# 21      36390
# 22       4162
# 23        841
# 24       6884
# 25      48694
# 26       5114
# 27        874
# 28       8675
# 29      65680
# 30       6485
# 31        777
# 32      12477
# 33      79838
# 34       7909
# 35        827
# 36      13245
# 37      93402
# 38       9364
# 39       1558
# 40      14593
# 41     104645
# 42      10689
# 43       2513
# 44      15229
# 45     112516
# 46      11816
# 47       2948

# %%
# df_ny_daily = df_ny.drop(columns="state").set_index("date")
# df_ny_daily = df_ny_daily.diff(periods=-1)

# %%
manuf_4state_m.dtypes
# Out:
# date             datetime64[ns]
# state                    object
# admin_janssen             int64
# admin_moderna             int64
# admin_pfizer              int64
# admin_unk                 int64
# dtype: object

# %%
case_manuf = manuf_4state_m.sort_values(["date", "state"])
case_manuf = case_manuf.join(case_manuf.groupby("state")[["admin_janssen", "admin_moderna", "admin_pfizer", "admin_unk"]].diff().fillna(0), rsuffix="_diff")

# %%
case_manuf = case_manuf.drop(columns=["admin_janssen", "admin_moderna", "admin_pfizer", "admin_unk"])

# %%
# converting state names to numerics to fit regression line
# CA:1, FL:2, NY:3, TX:4

numstate = {"CA":1, "FL":2, "NY":3, "TX":4}
case_manuf["state"] = case_manuf["state"].replace(numstate)

# %%
case_manuf.describe(include = 'all', datetime_is_numeric=True)
# Out:
#                                 date      state  admin_janssen_diff  \
# count                             56  56.000000           56.000000
# mean   2021-07-17 01:42:51.428571392   2.500000       117016.732143
# min              2021-01-01 00:00:00   1.000000            0.000000
# 25%              2021-04-01 00:00:00   1.750000        36431.750000
# 50%              2021-07-16 12:00:00   2.500000        75343.500000
# 75%              2021-11-01 00:00:00   3.250000       153654.500000
# max              2022-02-01 00:00:00   4.000000       731072.000000
# std                              NaN   1.128152       133971.429242
#
#        admin_moderna_diff  admin_pfizer_diff  admin_unk_diff
# count        5.600000e+01       5.600000e+01       56.000000
# mean         1.217038e+06       1.936151e+06     2911.196429
# min          0.000000e+00       0.000000e+00    -1485.000000
# 25%          5.652140e+05       1.219378e+06      187.500000
# 50%          9.475955e+05       1.562544e+06     1173.500000
# 75%          1.538006e+06       2.457557e+06     2513.500000
# max          4.850227e+06       6.633513e+06    16986.000000
# std          1.001521e+06       1.250359e+06     4383.984997

# %%
case_manuf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56 entries, 25705 to 71
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                56 non-null     datetime64[ns]
#  1   state               56 non-null     int64
#  2   admin_janssen_diff  56 non-null     float64
#  3   admin_moderna_diff  56 non-null     float64
#  4   admin_pfizer_diff   56 non-null     float64
#  5   admin_unk_diff      56 non-null     float64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 5.1 KB
